# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # The Pandas library

# %% [markdown]
# **From the Pandas documentation:**
#
# **pandas** is everyone's favorite data analyis library providing fast, flexible, and expressive data structures designed to work with *relational* or table-like data (SQL table or Excel spreadsheet). It is a fundamental high-level building block for doing practical, real world data analysis in Python.

# %% [markdown]
# # Introducing the most important objects: Series and DataFrames

# %%
# The importing convention
import pandas as pd

# %% [markdown]
# ## The Pandas DataFrames
#
# * Think of them as Excel “Sheets”, but for Python
# * They contain Columns, Rows, and Data
# * They are specific to Pandas (other languages do have them)
#
# <img src="img/dataframe.png">
#
# ## Excel Table
#
# <img src="img/excel_table.png">
#
#
# You can create a DataFrame from:
#
# * Dict of 1D ndarrays, lists, dicts, or Series
# * 2-D numpy.ndarray
# * From text, CSV, Excel files or databases
# * Many other ways
#
# Here's an example where we have set the Dates column to be the index and label for the rows.

# %% [markdown]
# # Main properties, operations and manipulations

# %% [markdown]
# ## Reading Excel File

# %% [markdown]
# filepath = r'https://raw.githubusercontent.com/ryansmccoy/spreadsheets-to-dataframes/master/data/WA_Fn-UseC_-HR-Employee-Attrition.xlsx'

# %%
filepath = "data\stock_data_simple.xlsx"

# %%
df = pd.read_excel(filepath)

# %% [markdown]
# ## The anatomy of a DataFrame

# %% [markdown]
# A DataFrame consists on three parts:
#
# 1. Index
# 2. Columns Names (Column Index)
# 3. Data
#
# The row and column labels can be accessed respectively by accessing the ``index`` and ``columns`` attributes:

# %%
df.columns
# Out:
# Index(['Symbol', 'Name', 'Sector', 'Price', 'Price Chg', 'Price % Chg',
#        'Vol Rate', 'Avg Dly $ Vol (000)', 'Mkt Val (Mil), USD', 'P/E Ratio',
#        'Company Description', 'Industry Group', 'ISIN', 'Major Industry',
#        'Exchange, Primary Listing', 'Exchange', 'Trading Country'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=499, step=1)

# %%
df.values
# Out:
# array([['APC.DE', 'Apple (Fra)', 'Technology', ..., 'No (NASDAQ, AAPL)',
#         'FRANKFURT', 'GERMANY'],
#        ['APCX.DE', 'Apple (Xet)', 'Technology', ..., 'No (NASDAQ, AAPL)',
#         'XETRA', 'GERMANY'],
#        ['AAPL', 'Apple Inc', 'Technology', ..., 'Yes', 'NASDAQ',
#         'UNITED STATES'],
#        ...,
#        ['FOXA', 'Twenty-First Cen Fx Cl A', 'Consumer Cyclical', ...,
#         'Yes', 'NASDAQ', 'UNITED STATES'],
#        ['ANZ.AU', 'Aus.And Nz.Banking Gp.', 'Financial', ..., 'Yes',
#         'AUSTRALIAN', 'AUSTRALIA'],
#        ['DEUT.IT', 'Deutsche Telekom (Mil)', 'Technology', ...,
#         'No (XETRA, DTEX.DE)', 'MILAN', 'ITALY']], dtype=object)

# %% [markdown]
# ## Viewing data

# %%
df.head()
# Out:
#     Symbol                      Name      Sector   Price  Price Chg  \
# 0   APC.DE               Apple (Fra)  Technology  410.00       0.00
# 1  APCX.DE               Apple (Xet)  Technology  408.50      -2.00
# 2     AAPL                 Apple Inc  Technology  554.25      -3.11
# 3  XONA.DE         Exxon Mobil (Fra)      Energy   73.20       0.00
# 4      WBK  Westpac Banking Corp Adr   Financial   27.99      -0.37
#
#    Price % Chg    Vol Rate  Avg Dly $ Vol (000)  Mkt Val (Mil), USD  \
# 0     0.000000 -100.000000                 1765              497751
# 1    -0.487211  -38.011541                 6159              495930
# 2    -0.557987  -25.368715              6099413              494697
# 3     0.000000 -100.000000                  322              435010
# 4    -1.304654   -8.477119                 3780              432467
#
#    P/E Ratio                                Company Description  \
# 0       14.0  APPLE INC. (APPLE) DESIGNS, MANUFACTURES AND M...
# 1       14.0  APPLE INC. (APPLE) DESIGNS, MANUFACTURES AND M...
# 2       14.0  MANUFACTURES PERSONAL COMPUTERS, MOBILE COMMUN...
# 3       13.0  EXXON MOBIL CORPORATION IS A MANUFACTURER AND ...
# 4       14.0  AUSTRALIAN BANK PROVIDING BANKING/RELATED FINA...
#
#   Industry Sector           Industry Group          ISIN  \
# 0        COMPUTER  Computer-Hardware/Perip  US0378331005
# 1        COMPUTER  Computer-Hardware/Perip  US0378331005
# 2        COMPUTER  Computer-Hardware/Perip  US0378331005
# 3          ENERGY       Oil&Gas-Integrated  US30231G1022
# 4           BANKS            Banks-Foreign  US9612143019
#
#           Major Industry   Headquarters Exchange, Primary Listing   Exchange  \
# 0                    NaN            NaN         No (NASDAQ, AAPL)  FRANKFURT
# 1                    NaN            NaN         No (NASDAQ, AAPL)      XETRA
# 2  Computer Data Storage  Cupertino, CA                       Yes     NASDAQ
# 3                    NaN            NaN            No (NYSE, XOM)  FRANKFURT
# 4      Bank-Money Center      AUSTRALIA                       Yes       NYSE
#
#   Trading Country
# 0         GERMANY
# 1         GERMANY
# 2   UNITED STATES
# 3         GERMANY
# 4   UNITED STATES

# %%
df.tail()
# Out:
#       Symbol                      Name             Sector  Price  Price Chg  \
# 494  DTEX.DE    Deutsche Telekom (Xet)         Technology  12.45     -0.195
# 495    BG.GB                  Bg Group             Energy  13.52      0.170
# 496     FOXA  Twenty-First Cen Fx Cl A  Consumer Cyclical  32.47     -0.140
# 497   ANZ.AU    Aus.And Nz.Banking Gp.          Financial  31.09      0.120
# 498  DEUT.IT    Deutsche Telekom (Mil)         Technology  12.40     -0.170
#
#      Price % Chg   Vol Rate  Avg Dly $ Vol (000)  Mkt Val (Mil), USD  \
# 494    -1.542722   4.413403               124042               75343
# 495     1.273885  58.304817                49949               75310
# 496    -0.429316 -26.565262               354171               75153
# 497     0.387472  -9.287592               169869               75132
# 498    -1.352426 -42.570255                  193               75071
#
#      P/E Ratio                                Company Description  \
# 494       23.0  DEUTSCHE TELEKOM AG IS A GERMANY-BASED INTEGRA...
# 495       16.0  BG GROUP PLC (BG GROUP) IS A NATURAL GAS COMPA...
# 496       25.0  GLOBAL MEDIA AND ENTERTAINMENT COMPANY ENGAGED...
# 497       13.0  AUSTRALIA AND NEW ZEALAND BANKING GROUP LIMITE...
# 498       23.0  DEUTSCHE TELEKOM AG IS A GERMANY-BASED INTEGRA...
#
#     Industry Sector           Industry Group          ISIN  \
# 494         TELECOM  Telecom Svcs-Integrated  DE0005557508
# 495          ENERGY       Oil&Gas-Integrated  GB0008762899
# 496           MEDIA        Media-Diversified  US90130A1016
# 497           BANKS       Banks-Money Center  AU000000ANZ3
# 498         TELECOM  Telecom Svcs-Integrated  DE0005557508
#
#               Major Industry  Headquarters Exchange, Primary Listing  \
# 494  Telecommunication Equip           NaN                       Yes
# 495                      NaN       Reading                       Yes
# 496         Media - Radio/Tv  New York, NY                       Yes
# 497        Bank-Money Center     Melbourne                       Yes
# 498  Telecommunication Equip           NaN       No (XETRA, DTEX.DE)
#
#        Exchange Trading Country
# 494       XETRA         GERMANY
# 495      LONDON  UNITED KINGDOM
# 496      NASDAQ   UNITED STATES
# 497  AUSTRALIAN       AUSTRALIA
# 498       MILAN           ITALY

# %% [markdown]
# ## Describe data quick statistical summary

# %%
df.describe()
# Out:
#               Price    Price Chg  Price % Chg     Vol Rate  \
# count  4.990000e+02   499.000000   499.000000   486.000000
# mean   3.937696e+03     7.238984     0.122020    23.230114
# std    5.928055e+04   112.630061     1.219567   426.729572
# min    1.500000e-01  -892.000000    -4.782609  -100.000000
# 25%    2.645500e+01    -0.070000    -0.291533  -100.000000
# 50%    5.466000e+01     0.000000     0.000000   -26.303047
# 75%    1.004450e+02     0.170000     0.351560    17.051872
# max    1.301000e+06  2000.000000     9.458656  5900.000000
#
#        Avg Dly $ Vol (000)  Mkt Val (Mil), USD    P/E Ratio
# count         4.990000e+02           499.00000   474.000000
# mean          1.222698e+06        137938.56513    30.776371
# std           1.469997e+07         69760.05240   127.496568
# min           0.000000e+00         75071.00000     2.000000
# 25%           3.350000e+01         88903.50000    12.000000
# 50%           3.030000e+02        113659.00000    16.000000
# 75%           8.808850e+04        175293.00000    21.000000
# max           2.975491e+08        497751.00000  1414.000000

# %% [markdown]
# ## Transpose your data

# %%
df.T
# Out:
#                                                                          0    \
# Symbol                                                                APC.DE
# Name                                                             Apple (Fra)
# Sector                                                            Technology
# Price                                                                  410.0
# Price Chg                                                                0.0
# Price % Chg                                                              0.0
# Vol Rate                                                              -100.0
# Avg Dly $ Vol (000)                                                     1765
# Mkt Val (Mil), USD                                                    497751
# P/E Ratio                                                               14.0
# Company Description        APPLE INC. (APPLE) DESIGNS, MANUFACTURES AND M...
# Industry Group                                       Computer-Hardware/Perip
# ISIN                                                            US0378331005
# Major Industry                                                           NaN
# Exchange, Primary Listing                                  No (NASDAQ, AAPL)
# Exchange                                                           FRANKFURT
# Trading Country                                                      GERMANY
#
#                                                                          1    \
# Symbol                                                               APCX.DE
# Name                                                             Apple (Xet)
# Sector                                                            Technology
# Price                                                                  408.5
# Price Chg                                                               -2.0
# Price % Chg                                                        -0.487211
# Vol Rate                                                          -38.011541
# Avg Dly $ Vol (000)                                                     6159
# Mkt Val (Mil), USD                                                    495930
# P/E Ratio                                                               14.0
# Company Description        APPLE INC. (APPLE) DESIGNS, MANUFACTURES AND M...
# Industry Group                                       Computer-Hardware/Perip
# ISIN                                                            US0378331005
# Major Industry                                                           NaN
# Exchange, Primary Listing                                  No (NASDAQ, AAPL)
# Exchange                                                               XETRA
# Trading Country                                                      GERMANY
#
#                                                                          2    \
# Symbol                                                                  AAPL
# Name                                                               Apple Inc
# Sector                                                            Technology
# Price                                                                 554.25
# Price Chg                                                              -3.11
# Price % Chg                                                        -0.557987
# Vol Rate                                                          -25.368715
# Avg Dly $ Vol (000)                                                  6099413
# Mkt Val (Mil), USD                                                    494697
# P/E Ratio                                                               14.0
# Company Description        MANUFACTURES PERSONAL COMPUTERS, MOBILE COMMUN...
# Industry Group                                       Computer-Hardware/Perip
# ISIN                                                            US0378331005
# Major Industry                                         Computer Data Storage
# Exchange, Primary Listing                                                Yes
# Exchange                                                              NASDAQ
# Trading Country                                                UNITED STATES
#
#                                                                          3    \
# Symbol                                                               XONA.DE
# Name                                                       Exxon Mobil (Fra)
# Sector                                                                Energy
# Price                                                                   73.2
# Price Chg                                                                0.0
# Price % Chg                                                              0.0
# Vol Rate                                                              -100.0
# Avg Dly $ Vol (000)                                                      322
# Mkt Val (Mil), USD                                                    435010
# P/E Ratio                                                               13.0
# Company Description        EXXON MOBIL CORPORATION IS A MANUFACTURER AND ...
# Industry Group                                            Oil&Gas-Integrated
# ISIN                                                            US30231G1022
# Major Industry                                                           NaN
# Exchange, Primary Listing                                     No (NYSE, XOM)
# Exchange                                                           FRANKFURT
# Trading Country                                                      GERMANY
#
#                                                                          4    \
# Symbol                                                                   WBK
# Name                                                Westpac Banking Corp Adr
# Sector                                                             Financial
# Price                                                                  27.99
# Price Chg                                                              -0.37
# Price % Chg                                                        -1.304654
# Vol Rate                                                           -8.477119
# Avg Dly $ Vol (000)                                                     3780
# Mkt Val (Mil), USD                                                    432467
# P/E Ratio                                                               14.0
# Company Description        AUSTRALIAN BANK PROVIDING BANKING/RELATED FINA...
# Industry Group                                                 Banks-Foreign
# ISIN                                                            US9612143019
# Major Industry                                             Bank-Money Center
# Exchange, Primary Listing                                                Yes
# Exchange                                                                NYSE
# Trading Country                                                UNITED STATES
#
#                                                                          5    \
# Symbol                                                                   XOM
# Name                                                        Exxon Mobil Corp
# Sector                                                                Energy
# Price                                                                  98.94
# Price Chg                                                               0.16
# Price % Chg                                                         0.161976
# Vol Rate                                                          -22.553492
# Avg Dly $ Vol (000)                                                  1201688
# Mkt Val (Mil), USD                                                    432220
# P/E Ratio                                                               13.0
# Company Description        ENGAGED IN THE EXPLORATION, PRODUCTION, TRANSP...
# Industry Group                                            Oil&Gas-Integrated
# ISIN                                                            US30231G1022
# Major Industry                                            Oil&Gas-Integrated
# Exchange, Primary Listing                                                Yes
# Exchange                                                                NYSE
# Trading Country                                                UNITED STATES
#
#                                                                          6    \
# Symbol                                                               XOAX.DE
# Name                                                       Exxon Mobil (Xet)
# Sector                                                                Energy
# Price                                                                  72.32
# Price Chg                                                              -0.39
# Price % Chg                                                        -0.536377
# Vol Rate                                                          -63.128791
# Avg Dly $ Vol (000)                                                      405
# Mkt Val (Mil), USD                                                    429768
# P/E Ratio                                                               13.0
# Company Description        EXXON MOBIL CORPORATION IS A MANUFACTURER AND ...
# Industry Group                                            Oil&Gas-Integrated
# ISIN                                                            US30231G1022
# Major Industry                                                           NaN
# Exchange, Primary Listing                                     No (NYSE, XOM)
# Exchange                                                               XETRA
# Trading Country                                                      GERMANY
#
#                                                                          7    \
# Symbol                                                                 KO.PE
# Name                                                         Coca Cola (Lim)
# Sector                                                       Consumer Staple
# Price                                                                  90.72
# Price Chg                                                                0.0
# Price % Chg                                                              0.0
# Vol Rate                                                                 NaN
# Avg Dly $ Vol (000)                                                        0
# Mkt Val (Mil), USD                                                    400612
# P/E Ratio                                                               47.0
# Company Description        THE COCA-COLA COMPANY IS A BEVERAGE COMPANY. T...
# Industry Group                                       Beverages-Non-Alcoholic
# ISIN                                                            US1912161007
# Major Industry                                      Beverage - Non-Alcoholic
# Exchange, Primary Listing                                      No (NYSE, KO)
# Exchange                                                                LIMA
# Trading Country                                                         PERU
#
#                                                                          8    \
# Symbol                                                                  GOOG
# Name                                                              Google Inc
# Sector                                                            Technology
# Price                                                                1156.22
# Price Chg                                                                7.6
# Price % Chg                                                         0.661663
# Vol Rate                                                             5.16121
# Avg Dly $ Vol (000)                                                  1838251
# Mkt Val (Mil), USD                                                    386278
# P/E Ratio                                                               27.0
# Company Description        PROVIDES ONLINE SEARCH, INTERNET CONTENT SERVI...
# Industry Group                                              Internet-Content
# ISIN                                                            US38259P5089
# Major Industry                                                      Internet
# Exchange, Primary Listing                                                Yes
# Exchange                                                              NASDAQ
# Trading Country                                                UNITED STATES
#
#                                                                          9    \
# Symbol                                                               GG@X.DE
# Name                                                        Google 'A' (Xet)
# Sector                                                            Technology
# Price                                                                 849.35
# Price Chg                                                                4.2
# Price % Chg                                                         0.496953
# Vol Rate                                                           19.008264
# Avg Dly $ Vol (000)                                                     1028
# Mkt Val (Mil), USD                                                    319639
# P/E Ratio                                                               31.0
# Company Description        GOOGLE INC. (GOOGLE) IS A GLOBAL TECHNOLOGY CO...
# Industry Group                                              Internet-Content
# ISIN                                                            US38259P5089
# Major Industry                                                           NaN
# Exchange, Primary Listing                                  No (NASDAQ, GOOG)
# Exchange                                                               XETRA
# Trading Country                                                      GERMANY
#
#                            ...  \
# Symbol                     ...
# Name                       ...
# Sector                     ...
# Price                      ...
# Price Chg                  ...
# Price % Chg                ...
# Vol Rate                   ...
# Avg Dly $ Vol (000)        ...
# Mkt Val (Mil), USD         ...
# P/E Ratio                  ...
# Company Description        ...
# Industry Group             ...
# ISIN                       ...
# Major Industry             ...
# Exchange, Primary Listing  ...
# Exchange                   ...
# Trading Country            ...
#
#                                                                          489  \
# Symbol                                                                   USB
# Name                                                         U S Bancorp Inc
# Sector                                                             Financial
# Price                                                                  41.46
# Price Chg                                                              -0.04
# Price % Chg                                                        -0.096385
# Vol Rate                                                            1.862741
# Avg Dly $ Vol (000)                                                   323937
# Mkt Val (Mil), USD                                                     75718
# P/E Ratio                                                               14.0
# Company Description        HOLDING COMPANY FOR U.S. BANK OPERATING THROUG...
# Industry Group                                          Banks-Super Regional
# ISIN                                                            US9029733048
# Major Industry                                           Bank-Super Regional
# Exchange, Primary Listing                                                Yes
# Exchange                                                                NYSE
# Trading Country                                                UNITED STATES
#
#                                                                          490  \
# Symbol                                                               DTEA.DE
# Name                                                Dt.Telekom Spn.Adr.(Fra)
# Sector                                                            Technology
# Price                                                                   12.5
# Price Chg                                                                0.0
# Price % Chg                                                              0.0
# Vol Rate                                                              -100.0
# Avg Dly $ Vol (000)                                                       18
# Mkt Val (Mil), USD                                                     75679
# P/E Ratio                                                               24.0
# Company Description        DEUTSCHE TELEKOM AG IS A GERMANY-BASED INTEGRA...
# Industry Group                                       Telecom Svcs-Integrated
# ISIN                                                            US2515661054
# Major Industry                                       Telecommunication Equip
# Exchange, Primary Listing                                    No (OTC, DTEGY)
# Exchange                                                           FRANKFURT
# Trading Country                                                      GERMANY
#
#                                                                          491  \
# Symbol                                                                DTE.NL
# Name                                                  Deutsche Telekom (Ams)
# Sector                                                            Technology
# Price                                                                   12.5
# Price Chg                                                              -0.02
# Price % Chg                                                        -0.159744
# Vol Rate                                                          -90.344828
# Avg Dly $ Vol (000)                                                       18
# Mkt Val (Mil), USD                                                     75676
# P/E Ratio                                                               23.0
# Company Description        DEUTSCHE TELEKOM AG IS A GERMANY-BASED INTEGRA...
# Industry Group                                       Telecom Svcs-Integrated
# ISIN                                                            DE0005557508
# Major Industry                                       Telecommunication Equip
# Exchange, Primary Listing                                No (XETRA, DTEX.DE)
# Exchange                                                     AMSTERDAM (AEX)
# Trading Country                                                  NETHERLANDS
#
#                                                                          492  \
# Symbol                                                                DTE.RO
# Name                                                  Deutsche Telekom (Bse)
# Sector                                                            Technology
# Price                                                                   56.5
# Price Chg                                                               1.25
# Price % Chg                                                         2.262443
# Vol Rate                                                              -100.0
# Avg Dly $ Vol (000)                                                        0
# Mkt Val (Mil), USD                                                     75526
# P/E Ratio                                                               22.0
# Company Description        DEUTSCHE TELEKOM AG IS A GERMANY-BASED INTEGRA...
# Industry Group                                       Telecom Svcs-Integrated
# ISIN                                                            DE0005557508
# Major Industry                                      Telecommunication Servce
# Exchange, Primary Listing                                No (XETRA, DTEX.DE)
# Exchange                                                           BUCHAREST
# Trading Country                                                      ROMANIA
#
#                                                                          493  \
# Symbol                                                               RIO1.DE
# Name                                                         Rio Tinto (Fra)
# Sector                                                        Basic Material
# Price                                                                  39.25
# Price Chg                                                                0.0
# Price % Chg                                                              0.0
# Vol Rate                                                              -100.0
# Avg Dly $ Vol (000)                                                      306
# Mkt Val (Mil), USD                                                     75417
# P/E Ratio                                                                NaN
# Company Description        RIO TINTO PLC (RIO TINTO) IS AN INTERNATIONAL ...
# Industry Group                                             Mining-Metal Ores
# ISIN                                                            GB0007188757
# Major Industry                                                           NaN
# Exchange, Primary Listing                                No (LONDON, RIO.GB)
# Exchange                                                           FRANKFURT
# Trading Country                                                      GERMANY
#
#                                                                          494  \
# Symbol                                                               DTEX.DE
# Name                                                  Deutsche Telekom (Xet)
# Sector                                                            Technology
# Price                                                                  12.45
# Price Chg                                                             -0.195
# Price % Chg                                                        -1.542722
# Vol Rate                                                            4.413403
# Avg Dly $ Vol (000)                                                   124042
# Mkt Val (Mil), USD                                                     75343
# P/E Ratio                                                               23.0
# Company Description        DEUTSCHE TELEKOM AG IS A GERMANY-BASED INTEGRA...
# Industry Group                                       Telecom Svcs-Integrated
# ISIN                                                            DE0005557508
# Major Industry                                       Telecommunication Equip
# Exchange, Primary Listing                                                Yes
# Exchange                                                               XETRA
# Trading Country                                                      GERMANY
#
#                                                                          495  \
# Symbol                                                                 BG.GB
# Name                                                                Bg Group
# Sector                                                                Energy
# Price                                                                  13.52
# Price Chg                                                               0.17
# Price % Chg                                                         1.273885
# Vol Rate                                                           58.304817
# Avg Dly $ Vol (000)                                                    49949
# Mkt Val (Mil), USD                                                     75310
# P/E Ratio                                                               16.0
# Company Description        BG GROUP PLC (BG GROUP) IS A NATURAL GAS COMPA...
# Industry Group                                            Oil&Gas-Integrated
# ISIN                                                            GB0008762899
# Major Industry                                                           NaN
# Exchange, Primary Listing                                                Yes
# Exchange                                                              LONDON
# Trading Country                                               UNITED KINGDOM
#
#                                                                          496  \
# Symbol                                                                  FOXA
# Name                                                Twenty-First Cen Fx Cl A
# Sector                                                     Consumer Cyclical
# Price                                                                  32.47
# Price Chg                                                              -0.14
# Price % Chg                                                        -0.429316
# Vol Rate                                                          -26.565262
# Avg Dly $ Vol (000)                                                   354171
# Mkt Val (Mil), USD                                                     75153
# P/E Ratio                                                               25.0
# Company Description        GLOBAL MEDIA AND ENTERTAINMENT COMPANY ENGAGED...
# Industry Group                                             Media-Diversified
# ISIN                                                            US90130A1016
# Major Industry                                              Media - Radio/Tv
# Exchange, Primary Listing                                                Yes
# Exchange                                                              NASDAQ
# Trading Country                                                UNITED STATES
#
#                                                                          497  \
# Symbol                                                                ANZ.AU
# Name                                                  Aus.And Nz.Banking Gp.
# Sector                                                             Financial
# Price                                                                  31.09
# Price Chg                                                               0.12
# Price % Chg                                                         0.387472
# Vol Rate                                                           -9.287592
# Avg Dly $ Vol (000)                                                   169869
# Mkt Val (Mil), USD                                                     75132
# P/E Ratio                                                               13.0
# Company Description        AUSTRALIA AND NEW ZEALAND BANKING GROUP LIMITE...
# Industry Group                                            Banks-Money Center
# ISIN                                                            AU000000ANZ3
# Major Industry                                             Bank-Money Center
# Exchange, Primary Listing                                                Yes
# Exchange                                                          AUSTRALIAN
# Trading Country                                                    AUSTRALIA
#
#                                                                          498
# Symbol                                                               DEUT.IT
# Name                                                  Deutsche Telekom (Mil)
# Sector                                                            Technology
# Price                                                                   12.4
# Price Chg                                                              -0.17
# Price % Chg                                                        -1.352426
# Vol Rate                                                          -42.570255
# Avg Dly $ Vol (000)                                                      193
# Mkt Val (Mil), USD                                                     75071
# P/E Ratio                                                               23.0
# Company Description        DEUTSCHE TELEKOM AG IS A GERMANY-BASED INTEGRA...
# Industry Group                                       Telecom Svcs-Integrated
# ISIN                                                            DE0005557508
# Major Industry                                       Telecommunication Equip
# Exchange, Primary Listing                                No (XETRA, DTEX.DE)
# Exchange                                                               MILAN
# Trading Country                                                        ITALY
#
# [17 rows x 499 columns]

# %% [markdown]
# ## Sort Your Data

# %%
df.sort_values("Mkt Val (Mil), USD", ascending=False)
# Out:
#       Symbol                      Name             Sector   Price  Price Chg  \
# 0     APC.DE               Apple (Fra)         Technology  410.00      0.000
# 1    APCX.DE               Apple (Xet)         Technology  408.50     -2.000
# 2       AAPL                 Apple Inc         Technology  554.25     -3.110
# 3    XONA.DE         Exxon Mobil (Fra)             Energy   73.20      0.000
# 4        WBK  Westpac Banking Corp Adr          Financial   27.99     -0.370
# ..       ...                       ...                ...     ...        ...
# 494  DTEX.DE    Deutsche Telekom (Xet)         Technology   12.45     -0.195
# 495    BG.GB                  Bg Group             Energy   13.52      0.170
# 496     FOXA  Twenty-First Cen Fx Cl A  Consumer Cyclical   32.47     -0.140
# 497   ANZ.AU    Aus.And Nz.Banking Gp.          Financial   31.09      0.120
# 498  DEUT.IT    Deutsche Telekom (Mil)         Technology   12.40     -0.170
#
#      Price % Chg    Vol Rate  Avg Dly $ Vol (000)  Mkt Val (Mil), USD  \
# 0       0.000000 -100.000000                 1765              497751
# 1      -0.487211  -38.011541                 6159              495930
# 2      -0.557987  -25.368715              6099413              494697
# 3       0.000000 -100.000000                  322              435010
# 4      -1.304654   -8.477119                 3780              432467
# ..           ...         ...                  ...                 ...
# 494    -1.542722    4.413403               124042               75343
# 495     1.273885   58.304817                49949               75310
# 496    -0.429316  -26.565262               354171               75153
# 497     0.387472   -9.287592               169869               75132
# 498    -1.352426  -42.570255                  193               75071
#
#      P/E Ratio                                Company Description  \
# 0         14.0  APPLE INC. (APPLE) DESIGNS, MANUFACTURES AND M...
# 1         14.0  APPLE INC. (APPLE) DESIGNS, MANUFACTURES AND M...
# 2         14.0  MANUFACTURES PERSONAL COMPUTERS, MOBILE COMMUN...
# 3         13.0  EXXON MOBIL CORPORATION IS A MANUFACTURER AND ...
# 4         14.0  AUSTRALIAN BANK PROVIDING BANKING/RELATED FINA...
# ..         ...                                                ...
# 494       23.0  DEUTSCHE TELEKOM AG IS A GERMANY-BASED INTEGRA...
# 495       16.0  BG GROUP PLC (BG GROUP) IS A NATURAL GAS COMPA...
# 496       25.0  GLOBAL MEDIA AND ENTERTAINMENT COMPANY ENGAGED...
# 497       13.0  AUSTRALIA AND NEW ZEALAND BANKING GROUP LIMITE...
# 498       23.0  DEUTSCHE TELEKOM AG IS A GERMANY-BASED INTEGRA...
#
#     Industry Sector           Industry Group          ISIN  \
# 0          COMPUTER  Computer-Hardware/Perip  US0378331005
# 1          COMPUTER  Computer-Hardware/Perip  US0378331005
# 2          COMPUTER  Computer-Hardware/Perip  US0378331005
# 3            ENERGY       Oil&Gas-Integrated  US30231G1022
# 4             BANKS            Banks-Foreign  US9612143019
# ..              ...                      ...           ...
# 494         TELECOM  Telecom Svcs-Integrated  DE0005557508
# 495          ENERGY       Oil&Gas-Integrated  GB0008762899
# 496           MEDIA        Media-Diversified  US90130A1016
# 497           BANKS       Banks-Money Center  AU000000ANZ3
# 498         TELECOM  Telecom Svcs-Integrated  DE0005557508
#
#               Major Industry   Headquarters Exchange, Primary Listing  \
# 0                        NaN            NaN         No (NASDAQ, AAPL)
# 1                        NaN            NaN         No (NASDAQ, AAPL)
# 2      Computer Data Storage  Cupertino, CA                       Yes
# 3                        NaN            NaN            No (NYSE, XOM)
# 4          Bank-Money Center      AUSTRALIA                       Yes
# ..                       ...            ...                       ...
# 494  Telecommunication Equip            NaN                       Yes
# 495                      NaN        Reading                       Yes
# 496         Media - Radio/Tv   New York, NY                       Yes
# 497        Bank-Money Center      Melbourne                       Yes
# 498  Telecommunication Equip            NaN       No (XETRA, DTEX.DE)
#
#        Exchange Trading Country
# 0     FRANKFURT         GERMANY
# 1         XETRA         GERMANY
# 2        NASDAQ   UNITED STATES
# 3     FRANKFURT         GERMANY
# 4          NYSE   UNITED STATES
# ..          ...             ...
# 494       XETRA         GERMANY
# 495      LONDON  UNITED KINGDOM
# 496      NASDAQ   UNITED STATES
# 497  AUSTRALIAN       AUSTRALIA
# 498       MILAN           ITALY
#
# [499 rows x 19 columns]

# %% [markdown]
# ## Selecting Your Data

# %% [markdown]
# You can treat a DataFrame like a dict of indexed Series objects. Getting, setting, and deleting columns works with the same syntax dictionary operations:

# %%
# Getting one column: .head() is just to print the first 5 values
df['Symbol']
# Out:
# 0       APC.DE
# 1      APCX.DE
# 2         AAPL
# 3      XONA.DE
# 4          WBK
#         ...
# 494    DTEX.DE
# 495      BG.GB
# 496       FOXA
# 497     ANZ.AU
# 498    DEUT.IT
# Name: Symbol, Length: 499, dtype: object

# %%
# Getting more than one column
df[['Symbol', 'Name','Sector']]
# Out:
#       Symbol                      Name             Sector
# 0     APC.DE               Apple (Fra)         Technology
# 1    APCX.DE               Apple (Xet)         Technology
# 2       AAPL                 Apple Inc         Technology
# 3    XONA.DE         Exxon Mobil (Fra)             Energy
# 4        WBK  Westpac Banking Corp Adr          Financial
# ..       ...                       ...                ...
# 494  DTEX.DE    Deutsche Telekom (Xet)         Technology
# 495    BG.GB                  Bg Group             Energy
# 496     FOXA  Twenty-First Cen Fx Cl A  Consumer Cyclical
# 497   ANZ.AU    Aus.And Nz.Banking Gp.          Financial
# 498  DEUT.IT    Deutsche Telekom (Mil)         Technology
#
# [499 rows x 3 columns]

# %%
# Get rows
df[0:3]
# Out:
#     Symbol         Name      Sector   Price  Price Chg  Price % Chg  \
# 0   APC.DE  Apple (Fra)  Technology  410.00       0.00     0.000000
# 1  APCX.DE  Apple (Xet)  Technology  408.50      -2.00    -0.487211
# 2     AAPL    Apple Inc  Technology  554.25      -3.11    -0.557987
#
#      Vol Rate  Avg Dly $ Vol (000)  Mkt Val (Mil), USD  P/E Ratio  \
# 0 -100.000000                 1765              497751       14.0
# 1  -38.011541                 6159              495930       14.0
# 2  -25.368715              6099413              494697       14.0
#
#                                  Company Description           Industry Group  \
# 0  APPLE INC. (APPLE) DESIGNS, MANUFACTURES AND M...  Computer-Hardware/Perip
# 1  APPLE INC. (APPLE) DESIGNS, MANUFACTURES AND M...  Computer-Hardware/Perip
# 2  MANUFACTURES PERSONAL COMPUTERS, MOBILE COMMUN...  Computer-Hardware/Perip
#
#            ISIN         Major Industry Exchange, Primary Listing   Exchange  \
# 0  US0378331005                    NaN         No (NASDAQ, AAPL)  FRANKFURT
# 1  US0378331005                    NaN         No (NASDAQ, AAPL)      XETRA
# 2  US0378331005  Computer Data Storage                       Yes     NASDAQ
#
#   Trading Country
# 0         GERMANY
# 1         GERMANY
# 2   UNITED STATES

# %%
df['Company Description'][10:15]
# Out:
# 10    GOOGLE INC. (GOOGLE) IS A GLOBAL TECHNOLOGY CO...
# 11    DEVELOPS OPERATING SYSTEMS, BUSINESS SOFTWARE,...
# 12    MICROSOFT CORPORATION IS ENGAGED IN DEVELOPING...
# 13    MICROSOFT CORPORATION IS ENGAGED IN DEVELOPING...
# 14    ENGAGES IN INSURANCE, FOODSERVICE OPERATIONS, ...
# Name: Company Description, dtype: object

# %%
df[10:15]
# Out:
#      Symbol                     Name             Sector   Price  Price Chg  \
# 10  GGQ1.DE         Google 'A' (Fra)         Technology  845.82       0.00
# 11     MSFT           Microsoft Corp         Technology   36.89       0.13
# 12   MSF.DE          Microsoft (Fra)         Technology   26.99       0.00
# 13  MSFX.DE          Microsoft (Xet)         Technology   26.79      -0.19
# 14     BRKB  Berkshire Hathaway Cl B  Capital Equipment  115.24      -0.61
#
#     Price % Chg    Vol Rate  Avg Dly $ Vol (000)  Mkt Val (Mil), USD  \
# 10     0.000000 -100.000000                  410              318311
# 11     0.353645   -4.880698              1468683              307956
# 12     0.000000 -100.000000                  508              306463
# 13    -0.704225   -5.157607                  568              304192
# 14    -0.526542  -20.105867               391758              284141
#
#     P/E Ratio                                Company Description  \
# 10       31.0  GOOGLE INC. (GOOGLE) IS A GLOBAL TECHNOLOGY CO...
# 11       13.0  DEVELOPS OPERATING SYSTEMS, BUSINESS SOFTWARE,...
# 12       14.0  MICROSOFT CORPORATION IS ENGAGED IN DEVELOPING...
# 13       14.0  MICROSOFT CORPORATION IS ENGAGED IN DEVELOPING...
# 14       20.0  ENGAGES IN INSURANCE, FOODSERVICE OPERATIONS, ...
#
#             Industry Group          ISIN         Major Industry  \
# 10        Internet-Content  US38259P5089                    NaN
# 11  Computer Sftwr-Desktop  US5949181045      Computer-Software
# 12  Computer Sftwr-Desktop  US5949181045      Computer-Software
# 13  Computer Sftwr-Desktop  US5949181045      Computer-Software
# 14  Diversified Operations  US0846707026  Diversified Operation
#
#    Exchange, Primary Listing   Exchange Trading Country
# 10         No (NASDAQ, GOOG)  FRANKFURT         GERMANY
# 11                       Yes     NASDAQ   UNITED STATES
# 12         No (NASDAQ, MSFT)  FRANKFURT         GERMANY
# 13         No (NASDAQ, MSFT)      XETRA         GERMANY
# 14                       Yes       NYSE   UNITED STATES

# %% [markdown]
# ### Selection by label

# %%
selected_companies = [1, 3, 4, 5]

# %%
df['Industry Group'].loc[selected_companies]
# Out:
# 1    Computer-Hardware/Perip
# 3         Oil&Gas-Integrated
# 4              Banks-Foreign
# 5         Oil&Gas-Integrated
# Name: Industry Group, dtype: object

# %%
df.loc[selected_companies]
# Out:
#     Symbol                      Name      Sector   Price  Price Chg  \
# 1  APCX.DE               Apple (Xet)  Technology  408.50      -2.00
# 3  XONA.DE         Exxon Mobil (Fra)      Energy   73.20       0.00
# 4      WBK  Westpac Banking Corp Adr   Financial   27.99      -0.37
# 5      XOM          Exxon Mobil Corp      Energy   98.94       0.16
#
#    Price % Chg    Vol Rate  Avg Dly $ Vol (000)  Mkt Val (Mil), USD  \
# 1    -0.487211  -38.011541                 6159              495930
# 3     0.000000 -100.000000                  322              435010
# 4    -1.304654   -8.477119                 3780              432467
# 5     0.161976  -22.553492              1201688              432220
#
#    P/E Ratio                                Company Description  \
# 1       14.0  APPLE INC. (APPLE) DESIGNS, MANUFACTURES AND M...
# 3       13.0  EXXON MOBIL CORPORATION IS A MANUFACTURER AND ...
# 4       14.0  AUSTRALIAN BANK PROVIDING BANKING/RELATED FINA...
# 5       13.0  ENGAGED IN THE EXPLORATION, PRODUCTION, TRANSP...
#
#             Industry Group          ISIN      Major Industry  \
# 1  Computer-Hardware/Perip  US0378331005                 NaN
# 3       Oil&Gas-Integrated  US30231G1022                 NaN
# 4            Banks-Foreign  US9612143019   Bank-Money Center
# 5       Oil&Gas-Integrated  US30231G1022  Oil&Gas-Integrated
#
#   Exchange, Primary Listing   Exchange Trading Country
# 1         No (NASDAQ, AAPL)      XETRA         GERMANY
# 3            No (NYSE, XOM)  FRANKFURT         GERMANY
# 4                       Yes       NYSE   UNITED STATES
# 5                       Yes       NYSE   UNITED STATES

# %%
# Getting a single value
df.loc[1,'Company Description']
# Out:
# "APPLE INC. (APPLE) DESIGNS, MANUFACTURES AND MARKETS MOBILE COMMUNICATION AND MEDIA DEVICES, PERSONAL COMPUTERS, AND PORTABLE DIGITAL MUSIC PLAYERS, AND SELLS A VARIETY OF RELATED SOFTWARE, SERVICES, PERIPHERALS, NETWORKING SOLUTIONS, AND THIRD-PARTY DIGITAL CONTENT AND APPLICATIONS. THE COMPANY'S PRODUCTS AND SERVICES INCLUDE IPHONE, IPAD, MAC, IPOD, APPLE TV, A PORTFOLIO OF CONSUMER AND PROFESSIONAL SOFTWARE APPLICATIONS, THE IOS AND OS X OPERATING SYSTEMS, ICLOUD, AND A VARIETY OF ACCESSORY, SERVICE AND SUPPORT OFFERINGS. IN MARCH 2013, THE COMPANY ACQUIRED A SILICON VALLEY STARTUP, WIFISLAM, WHICH MAKES MAPPING APPLICATIONS FOR SMART PHONES. EFFECTIVE JULY 19, 2013, APPLE ACQUIRED LOCATIONARY INC. EFFECTIVE JULY 20, 2013, APPLE ACQUIRED HOPSTOP.COM INC. EFFECTIVE AUGUST 28, 2013, APPLE ACQUIRED ALGOTRIM AB, A MALMO-BASED DEVELOPER OF PREPACKAGED SOFTWARE. IN NOVEMBER 2013, APPLE BOUGHT PRIMESE"

# %% [markdown]
# It is also possible to select by position using the *iloc* method

# %% [markdown]
# ## Answering simple questions about a dataset

# %% [markdown]
# ### How many companies are there by Sector?

# %%
df['Sector'].value_counts()
# Out:
# Financial            116
# Technology            89
# Energy                75
# Health Care           63
# Consumer Staple       52
# Capital Equipment     32
# Consumer Cyclical     28
# Retail                21
# Basic Material        20
# Transportation         3
# Name: Sector, dtype: int64

# %% [markdown]
# ### What is the average Market Capitalization?

# %%
df['Mkt Val (Mil), USD'].mean()
# Out:
# 137938.5651302605

# %% [markdown]
# ### What is the most frequest sector?

# %%
df['Sector'].describe()
# Out:
# count           499
# unique           10
# top       Financial
# freq            116
# Name: Sector, dtype: object

# %% [markdown]
# ## Who are the 5 largest companies?

# %%
df.sort_values('Mkt Val (Mil), USD', ascending=False)[:5]
# Out:
#     Symbol                      Name      Sector   Price  Price Chg  \
# 0   APC.DE               Apple (Fra)  Technology  410.00       0.00
# 1  APCX.DE               Apple (Xet)  Technology  408.50      -2.00
# 2     AAPL                 Apple Inc  Technology  554.25      -3.11
# 3  XONA.DE         Exxon Mobil (Fra)      Energy   73.20       0.00
# 4      WBK  Westpac Banking Corp Adr   Financial   27.99      -0.37
#
#    Price % Chg    Vol Rate  Avg Dly $ Vol (000)  Mkt Val (Mil), USD  \
# 0     0.000000 -100.000000                 1765              497751
# 1    -0.487211  -38.011541                 6159              495930
# 2    -0.557987  -25.368715              6099413              494697
# 3     0.000000 -100.000000                  322              435010
# 4    -1.304654   -8.477119                 3780              432467
#
#    P/E Ratio                                Company Description  \
# 0       14.0  APPLE INC. (APPLE) DESIGNS, MANUFACTURES AND M...
# 1       14.0  APPLE INC. (APPLE) DESIGNS, MANUFACTURES AND M...
# 2       14.0  MANUFACTURES PERSONAL COMPUTERS, MOBILE COMMUN...
# 3       13.0  EXXON MOBIL CORPORATION IS A MANUFACTURER AND ...
# 4       14.0  AUSTRALIAN BANK PROVIDING BANKING/RELATED FINA...
#
#             Industry Group          ISIN         Major Industry  \
# 0  Computer-Hardware/Perip  US0378331005                    NaN
# 1  Computer-Hardware/Perip  US0378331005                    NaN
# 2  Computer-Hardware/Perip  US0378331005  Computer Data Storage
# 3       Oil&Gas-Integrated  US30231G1022                    NaN
# 4            Banks-Foreign  US9612143019      Bank-Money Center
#
#   Exchange, Primary Listing   Exchange Trading Country
# 0         No (NASDAQ, AAPL)  FRANKFURT         GERMANY
# 1         No (NASDAQ, AAPL)      XETRA         GERMANY
# 2                       Yes     NASDAQ   UNITED STATES
# 3            No (NYSE, XOM)  FRANKFURT         GERMANY
# 4                       Yes       NYSE   UNITED STATES

# %% [markdown]
# # Boolean Indexing
# Using a single column's values to select data

# %% [markdown]
# ## Further questions

# %%
df.columns
# Out:
# Index(['Symbol', 'Name', 'Sector', 'Price', 'Price Chg', 'Price % Chg',
#        'Vol Rate', 'Avg Dly $ Vol (000)', 'Mkt Val (Mil), USD', 'P/E Ratio',
#        'Company Description', 'Industry Group', 'ISIN', 'Major Industry',
#        'Exchange, Primary Listing', 'Exchange', 'Trading Country'],
#       dtype='object')

# %% [markdown]
# ### Give me the list of the companies in the Technology Sector

# %%
df['Sector'] == 'Technology'
# Out:
# 0       True
# 1       True
# 2       True
# 3      False
# 4      False
#        ...
# 494     True
# 495    False
# 496    False
# 497    False
# 498     True
# Name: Sector, Length: 499, dtype: bool

# %% [markdown]
# We can use a boolean series to index a Series or a DataFrame, this is called "Masking" or boolean indexing.

# %%
df.loc[df['Sector'] == 'Technology']
# Out:
#       Symbol                      Name      Sector    Price  Price Chg  \
# 0     APC.DE               Apple (Fra)  Technology   410.00      0.000
# 1    APCX.DE               Apple (Xet)  Technology   408.50     -2.000
# 2       AAPL                 Apple Inc  Technology   554.25     -3.110
# 8       GOOG                Google Inc  Technology  1156.22      7.600
# 9    GG@X.DE          Google 'A' (Xet)  Technology   849.35      4.200
# ..       ...                       ...         ...      ...        ...
# 490  DTEA.DE  Dt.Telekom Spn.Adr.(Fra)  Technology    12.50      0.000
# 491   DTE.NL    Deutsche Telekom (Ams)  Technology    12.50     -0.020
# 492   DTE.RO    Deutsche Telekom (Bse)  Technology    56.50      1.250
# 494  DTEX.DE    Deutsche Telekom (Xet)  Technology    12.45     -0.195
# 498  DEUT.IT    Deutsche Telekom (Mil)  Technology    12.40     -0.170
#
#      Price % Chg    Vol Rate  Avg Dly $ Vol (000)  Mkt Val (Mil), USD  \
# 0       0.000000 -100.000000                 1765              497751
# 1      -0.487211  -38.011541                 6159              495930
# 2      -0.557987  -25.368715              6099413              494697
# 8       0.661663    5.161210              1838251              386278
# 9       0.496953   19.008264                 1028              319639
# ..           ...         ...                  ...                 ...
# 490     0.000000 -100.000000                   18               75679
# 491    -0.159744  -90.344828                   18               75676
# 492     2.262443 -100.000000                    0               75526
# 494    -1.542722    4.413403               124042               75343
# 498    -1.352426  -42.570255                  193               75071
#
#      P/E Ratio                                Company Description  \
# 0         14.0  APPLE INC. (APPLE) DESIGNS, MANUFACTURES AND M...
# 1         14.0  APPLE INC. (APPLE) DESIGNS, MANUFACTURES AND M...
# 2         14.0  MANUFACTURES PERSONAL COMPUTERS, MOBILE COMMUN...
# 8         27.0  PROVIDES ONLINE SEARCH, INTERNET CONTENT SERVI...
# 9         31.0  GOOGLE INC. (GOOGLE) IS A GLOBAL TECHNOLOGY CO...
# ..         ...                                                ...
# 490       24.0  DEUTSCHE TELEKOM AG IS A GERMANY-BASED INTEGRA...
# 491       23.0  DEUTSCHE TELEKOM AG IS A GERMANY-BASED INTEGRA...
# 492       22.0  DEUTSCHE TELEKOM AG IS A GERMANY-BASED INTEGRA...
# 494       23.0  DEUTSCHE TELEKOM AG IS A GERMANY-BASED INTEGRA...
# 498       23.0  DEUTSCHE TELEKOM AG IS A GERMANY-BASED INTEGRA...
#
#               Industry Group          ISIN            Major Industry  \
# 0    Computer-Hardware/Perip  US0378331005                       NaN
# 1    Computer-Hardware/Perip  US0378331005                       NaN
# 2    Computer-Hardware/Perip  US0378331005     Computer Data Storage
# 8           Internet-Content  US38259P5089                  Internet
# 9           Internet-Content  US38259P5089                       NaN
# ..                       ...           ...                       ...
# 490  Telecom Svcs-Integrated  US2515661054   Telecommunication Equip
# 491  Telecom Svcs-Integrated  DE0005557508   Telecommunication Equip
# 492  Telecom Svcs-Integrated  DE0005557508  Telecommunication Servce
# 494  Telecom Svcs-Integrated  DE0005557508   Telecommunication Equip
# 498  Telecom Svcs-Integrated  DE0005557508   Telecommunication Equip
#
#     Exchange, Primary Listing         Exchange Trading Country
# 0           No (NASDAQ, AAPL)        FRANKFURT         GERMANY
# 1           No (NASDAQ, AAPL)            XETRA         GERMANY
# 2                         Yes           NASDAQ   UNITED STATES
# 8                         Yes           NASDAQ   UNITED STATES
# 9           No (NASDAQ, GOOG)            XETRA         GERMANY
# ..                        ...              ...             ...
# 490           No (OTC, DTEGY)        FRANKFURT         GERMANY
# 491       No (XETRA, DTEX.DE)  AMSTERDAM (AEX)     NETHERLANDS
# 492       No (XETRA, DTEX.DE)        BUCHAREST         ROMANIA
# 494                       Yes            XETRA         GERMANY
# 498       No (XETRA, DTEX.DE)            MILAN           ITALY
#
# [89 rows x 17 columns]

# %% [markdown]
# ### Give me the list of the companies in the Technology Sector and United States

# %%
df.loc[(df['Sector'] == 'Technology') & (df['Trading Country'] == 'UNITED STATES')]
# Out:
#     Symbol                      Name      Sector    Price  Price Chg  \
# 2     AAPL                 Apple Inc  Technology   554.25      -3.11
# 8     GOOG                Google Inc  Technology  1156.22       7.60
# 11    MSFT            Microsoft Corp  Technology    36.89       0.13
# 73     IBM    Intl Business Machines  Technology   188.76       1.02
# 87     CHL      China Mobile Ltd Adr  Technology    50.17      -0.22
# 98     VOD    Vodafone Group Plc Adr  Technology    38.83      -0.10
# 119      T               A T & T Inc  Technology    33.96       0.17
# 130   ORCL               Oracle Corp  Technology    38.29      -0.12
# 160     FB         Facebook Inc Cl A  Technology    57.19      -0.41
# 167  CMCSA         Comcast Corp Cl A  Technology    53.54      -0.53
# 174     VZ    Verizon Communications  Technology    48.53       0.26
# 179  CMCSK  Comcast Corp Cla Special  Technology    51.69      -0.37
# 196   INTC                Intel Corp  Technology    26.54      -0.13
# 209   QCOM              Qualcomm Inc  Technology    74.72       0.21
# 215   CSCO         Cisco Systems Inc  Technology    22.78       0.00
# 310    SAP              S A P Ag Adr  Technology    82.81      -0.20
# 342    TSM  Taiwan Semiconductor Adr  Technology    18.15       0.59
# 455   AMOV   America Movil Sab Adr A  Technology    21.85      -0.37
# 483    TEF        Telefonica S A Adr  Technology    16.85      -0.05
#
#      Price % Chg    Vol Rate  Avg Dly $ Vol (000)  Mkt Val (Mil), USD  \
# 2      -0.557987  -25.368715              6099413              494697
# 8       0.661663    5.161210              1838251              386278
# 11      0.353645   -4.880698              1468683              307956
# 73      0.543304   -1.631052               909319              204965
# 87     -0.436594    3.262383                50662              201693
# 98     -0.256871  -34.011403               297016              191470
# 119     0.503107  -23.260207               713753              178901
# 130    -0.312418  -28.108149               718701              172205
# 160    -0.711805  -48.250630              3840670              145274
# 167    -0.980210    2.945779               532114              140029
# 174     0.538636   26.151711               542545              138795
# 179    -0.710718   11.610547                96941              135681
# 196    -0.487439   51.838758               823050              131930
# 209     0.281841   -0.429965               765955              126234
# 215     0.000000  -19.392564              1098805              121795
# 310    -0.240934   -0.564297                76494               98709
# 342     3.359908  112.541355               178871               94120
# 455    -1.665166  -31.666667                  133               78354
# 483    -0.295857  -25.918459                15088               76246
#
#      P/E Ratio                                Company Description  \
# 2         14.0  MANUFACTURES PERSONAL COMPUTERS, MOBILE COMMUN...
# 8         27.0  PROVIDES ONLINE SEARCH, INTERNET CONTENT SERVI...
# 11        13.0  DEVELOPS OPERATING SYSTEMS, BUSINESS SOFTWARE,...
# 73        12.0  PROVIDES IT CONSULTING SERVICES AND COMPUTER H...
# 87        10.0  HONG KONG-BASED PROVIDER OF DIGITAL WIRELESS V...
# 98        25.0  U.K.-BASED PROVIDER OF DIGITAL WIRELESS VOICE ...
# 119       14.0  PROVIDES LOCAL EXCHANGE, LONG DISTANCE, NETWOR...
# 130       14.0  DEVELOPS DATABASE, MIDDLEWARE AND BUSINESS APP...
# 160       79.0  PROVIDES A SOCIAL NETWORKING PLATFORM ENABLING...
# 167       23.0  PROVIDES VIDEO, INTERNET, PHONE, NETWORK, AND ...
# 174       19.0  PROVIDES LOCAL EXCHANGE, NETWORK ACCESS, DATA,...
# 179       22.0  PROVIDES VIDEO, INTERNET, PHONE, NETWORK, AND ...
# 196       14.0  MANUFACTURES MICROPROCESSORS, CHIPSETS, NETWOR...
# 209       17.0  DESIGNS CDMA-BASED/RF/POWER MANAGEMENT ICS AND...
# 215       11.0  MANUFACTURES SWITCHES, ROUTERS AND OTHER NETWO...
# 310       20.0  GERMAN DEVELOPER OF BUSINESS OPERATIONS MANAGE...
# 342       15.0  TAIWANESE MANUFACTURER OF LOGIC/MIXED-SIGNAL I...
# 455       12.0  MEXICAN PROVIDER OF WIRELESS VOICE AND DATA SE...
# 483       15.0  SPANISH PROVIDER OF LOCAL EXCHANGE, LONG DISTA...
#
#                Industry Group          ISIN            Major Industry  \
# 2     Computer-Hardware/Perip  US0378331005     Computer Data Storage
# 8            Internet-Content  US38259P5089                  Internet
# 11     Computer Sftwr-Desktop  US5949181045         Computer-Software
# 73     Computer-Tech Services  US4592001014         Computer-Services
# 87      Telecom Svcs- Foreign  US16941M1099  Telecommunication Servce
# 98      Telecom Svcs- Foreign  US92857W2098  Telecommunication Servce
# 119   Telecom Svcs-Integrated  US00206R1023  Telecommunication Servce
# 130   Computer Sftwr-Database  US68389X1054         Computer-Software
# 160          Internet-Content  US30303M1027                  Internet
# 167   Telecom Svcs-Cable/Satl  US20030N1019  Telecommunication Servce
# 174   Telecom Svcs-Integrated  US92343V1044  Telecommunication Servce
# 179   Telecom Svcs-Cable/Satl  US20030N2009  Telecommunication Servce
# 196    Elec-Semiconductor Mfg  US4581401001  Electronic-Semiconductor
# 209  Elec-Semicondctor Fablss  US7475251036  Electronic-Semiconductor
# 215       Computer-Networking  US17275R1023         Computer-Software
# 310  Computer Sftwr-Enterprse  US8030542042         Computer-Software
# 342    Elec-Semiconductor Mfg  US8740391003  Electronic-Semiconductor
# 455     Telecom Svcs- Foreign  US02364W2044  Telecommunication Servce
# 483     Telecom Svcs- Foreign  US8793822086  Telecommunication Servce
#
#     Exchange, Primary Listing Exchange Trading Country
# 2                         Yes   NASDAQ   UNITED STATES
# 8                         Yes   NASDAQ   UNITED STATES
# 11                        Yes   NASDAQ   UNITED STATES
# 73                        Yes     NYSE   UNITED STATES
# 87                        Yes     NYSE   UNITED STATES
# 98                        Yes   NASDAQ   UNITED STATES
# 119                       Yes     NYSE   UNITED STATES
# 130                       Yes     NYSE   UNITED STATES
# 160                       Yes   NASDAQ   UNITED STATES
# 167                       Yes   NASDAQ   UNITED STATES
# 174                       Yes     NYSE   UNITED STATES
# 179                       Yes   NASDAQ   UNITED STATES
# 196                       Yes   NASDAQ   UNITED STATES
# 209                       Yes   NASDAQ   UNITED STATES
# 215                       Yes   NASDAQ   UNITED STATES
# 310                       Yes     NYSE   UNITED STATES
# 342                       Yes     NYSE   UNITED STATES
# 455                       Yes   NASDAQ   UNITED STATES
# 483                       Yes     NYSE   UNITED STATES

# %% [markdown]
# **Grouping operations**: Split-Apply-Combine operation.
#
# By **gourping** or **group by** operations we are referring to a process involving one or more of the following steps:
#
# - **Splitting** the data into groups based on some criteria
# - **Applying** a function to each group independently
# - **Combining** the results into a data structure

# %% [markdown]
# <img src="img/split_apply_combine.png">
#
# <b>Step1 (Split): </b> The <i>groupby</i> operation <b><i>splits</b></i> the dataframe into a group of dataframes based on some criteria. Note that the grouped object is <i>not</i> a dataframe. It is a GroupBy object. It has a dictionary-like structure and is also iterable.
#
# <b>Step 2 (Analyze):</b> Once we have a grouped object we can <b><i>apply</b></i> functions or run analysis to each group, set of groups, or the entire group.
#
# <b>Step 3 (Combine):</b> We can also <b><i>combine</b></i> the results of the analysis into a new data structure(s).

# %% [markdown]
# Since we are only interested in the employees with "Low" and "Very High" JobSatisfaction levels, let's create a new DataFrame containing only those observations.

# %%
subset_of_interest = df.loc[(df['Sector'] == "Technology") | (df['Sector'] == "Energy")]

subset_of_interest.shape
# Out:
# (164, 19)

# %% [markdown]
# Since our JobSatisfaction variable had 4 categories, this categories have stayed in the series of this new DataFrame:

# %%
subset_of_interest['Sector'].value_counts()
# Out:
# Technology    89
# Energy        75
# Name: Sector, dtype: int64

# %% [markdown]
# Let's remove those categories we won't be using:

# %%
subset_of_interest['Sector'].value_counts()
# Out:
# Technology    89
# Energy        75
# Name: Sector, dtype: int64

# %% [markdown]
# Now we have only the employees we are interested in, we can now compare accross the variables we wanted. First let's split our new DataFrame into groups.

# %%
grouped = subset_of_interest.groupby('Sector')

# %%
grouped.groups
# Out:
# {'Energy': [3, 5, 6, 28, 35, 42, 43, 44, 45, 86, 97, 101, 110, 151, 152, 154, 155, 156, 157, 161, 162, 163, 164, 165, 166, 168, 169, 170, 171, 172, 173, 176, 184, 228, 229, 230, 231, 234, 319, 321, 322, 325, 348, 352, 353, 355, 362, 364, 384, 385, 386, 387, 388, 390, 396, 398, 400, 410, 418, 424, 427, 430, 433, 435, 436, 440, 441, 443, 444, 446, 451, 467, 485, 487, 495], 'Technology': [0, 1, 2, 8, 9, 10, 11, 12, 13, 24, 67, 68, 73, 75, 76, 79, 81, 85, 87, 88, 98, 99, 102, 103, 104, 105, 115, 116, 117, 119, 120, 127, 128, 130, 160, 167, 174, 179, 182, 190, 194, 195, 196, 209, 210, 211, 212, 213, 214, 215, 216, 217, 218, 219, 220, 221, 223, 224, 226, 227, 244, 258, 281, 283, 287, 288, 289, 290, 291, 297, 301, 310, 342, 359, 360, 455, 470, 472, 473, 478, 480, 482, 483, 486, 490, 491, 492, 494, 498]}

# %%
grouped.get_group('Energy').head()
# Out:
#      Symbol                     Name  Sector  Price  Price Chg  Price % Chg  \
# 3   XONA.DE        Exxon Mobil (Fra)  Energy  73.20       0.00     0.000000
# 5       XOM         Exxon Mobil Corp  Energy  98.94       0.16     0.161976
# 6   XOAX.DE        Exxon Mobil (Xet)  Energy  72.32      -0.39    -0.536377
# 28   CVX.BE      Chevron Cert. (Bru)  Energy  87.29       0.29     0.333333
# 35     RDSB  Royal Dutch Shell B Ads  Energy  75.42       0.35     0.466231
#
#       Vol Rate  Avg Dly $ Vol (000)  Mkt Val (Mil), USD  P/E Ratio  \
# 3  -100.000000                  322              435010       13.0
# 5   -22.553492              1201688              432220       13.0
# 6   -63.128791                  405              429768       13.0
# 28  766.666667                    5              256073        NaN
# 35   92.496979                68336              241329       11.0
#
#                                   Company Description Industry Sector  \
# 3   EXXON MOBIL CORPORATION IS A MANUFACTURER AND ...          ENERGY
# 5   ENGAGED IN THE EXPLORATION, PRODUCTION, TRANSP...          ENERGY
# 6   EXXON MOBIL CORPORATION IS A MANUFACTURER AND ...          ENERGY
# 28                                                NaN          ENERGY
# 35  ENGAGED IN EXPLORATION, PRODUCTION AND REFININ...          ENERGY
#
#         Industry Group          ISIN      Major Industry Headquarters  \
# 3   Oil&Gas-Integrated  US30231G1022                 NaN          NaN
# 5   Oil&Gas-Integrated  US30231G1022  Oil&Gas-Integrated   Irving, TX
# 6   Oil&Gas-Integrated  US30231G1022                 NaN          NaN
# 28  Oil&Gas-Integrated  BE0004589306                 NaN          NaN
# 35  Oil&Gas-Integrated  US7802591070  Oil&Gas-Integrated  NETHERLANDS
#
#    Exchange, Primary Listing   Exchange Trading Country
# 3             No (NYSE, XOM)  FRANKFURT         GERMANY
# 5                        Yes       NYSE   UNITED STATES
# 6             No (NYSE, XOM)      XETRA         GERMANY
# 28                       Yes   BRUSSELS         BELGIUM
# 35                       Yes       NYSE   UNITED STATES

# %% [markdown]
# #### Age

# %%
grouped['P/E Ratio']

# %%
grouped['P/E Ratio'].mean()
# Out:
# Sector
# Energy        10.671233
# Technology    19.068182
# Name: P/E Ratio, dtype: float64

# %%
grouped['P/E Ratio'].describe()
# Out:
#             count       mean        std  min   25%   50%   75%   max
# Sector
# Energy       73.0  10.671233   4.160178  2.0   8.0  11.0  13.0  20.0
# Technology   88.0  19.068182  11.357104  6.0  13.0  16.0  23.0  79.0

# %%
grouped['P/E Ratio'].describe().unstack()
# Out:
#        Sector
# count  Energy        73.000000
#        Technology    88.000000
# mean   Energy        10.671233
#        Technology    19.068182
# std    Energy         4.160178
#        Technology    11.357104
# min    Energy         2.000000
#        Technology     6.000000
# 25%    Energy         8.000000
#        Technology    13.000000
# 50%    Energy        11.000000
#        Technology    16.000000
# 75%    Energy        13.000000
#        Technology    23.000000
# max    Energy        20.000000
#        Technology    79.000000
# dtype: float64

# %% [markdown]
# #### Department

# %%
grouped['Industry Group'].value_counts().unstack()
# Out:
# Industry Group  Computer Sftwr-Database  Computer Sftwr-Desktop  \
# Sector
# Energy                              NaN                     NaN
# Technology                          3.0                     5.0
#
# Industry Group  Computer Sftwr-Enterprse  Computer-Hardware/Perip  \
# Sector
# Energy                               NaN                      NaN
# Technology                           7.0                      3.0
#
# Industry Group  Computer-Networking  Computer-Tech Services  \
# Sector
# Energy                          NaN                     NaN
# Technology                      4.0                     4.0
#
# Industry Group  Elec-Misc Products  Elec-Semicondctor Fablss  \
# Sector
# Energy                         NaN                       NaN
# Technology                    10.0                       1.0
#
# Industry Group  Elec-Semiconductor Mfg  Internet-Content  \
# Sector
# Energy                             NaN               NaN
# Technology                         7.0               7.0
#
# Industry Group  Oil&Gas-Field Services  Oil&Gas-Integrated  \
# Sector
# Energy                             9.0                55.0
# Technology                         NaN                 NaN
#
# Industry Group  Oil&Gas-Intl Expl&Prod  Oil&Gas-U S Expl&Prod  \
# Sector
# Energy                            10.0                    1.0
# Technology                         NaN                    NaN
#
# Industry Group  Telecom Svcs- Foreign  Telecom Svcs-Cable/Satl  \
# Sector
# Energy                            NaN                      NaN
# Technology                        9.0                      3.0
#
# Industry Group  Telecom Svcs-Integrated  Telecom Svcs-Wireless
# Sector
# Energy                              NaN                    NaN
# Technology                         23.0                    3.0

# %%
100 * grouped['Industry Group'].value_counts(normalize=True).unstack()
# Out:
# Industry Group  Computer Sftwr-Database  Computer Sftwr-Desktop  \
# Sector
# Energy                              NaN                     NaN
# Technology                     3.370787                5.617978
#
# Industry Group  Computer Sftwr-Enterprse  Computer-Hardware/Perip  \
# Sector
# Energy                               NaN                      NaN
# Technology                      7.865169                 3.370787
#
# Industry Group  Computer-Networking  Computer-Tech Services  \
# Sector
# Energy                          NaN                     NaN
# Technology                 4.494382                4.494382
#
# Industry Group  Elec-Misc Products  Elec-Semicondctor Fablss  \
# Sector
# Energy                         NaN                       NaN
# Technology               11.235955                  1.123596
#
# Industry Group  Elec-Semiconductor Mfg  Internet-Content  \
# Sector
# Energy                             NaN               NaN
# Technology                    7.865169          7.865169
#
# Industry Group  Oil&Gas-Field Services  Oil&Gas-Integrated  \
# Sector
# Energy                            12.0           73.333333
# Technology                         NaN                 NaN
#
# Industry Group  Oil&Gas-Intl Expl&Prod  Oil&Gas-U S Expl&Prod  \
# Sector
# Energy                       13.333333               1.333333
# Technology                         NaN                    NaN
#
# Industry Group  Telecom Svcs- Foreign  Telecom Svcs-Cable/Satl  \
# Sector
# Energy                            NaN                      NaN
# Technology                   10.11236                 3.370787
#
# Industry Group  Telecom Svcs-Integrated  Telecom Svcs-Wireless
# Sector
# Energy                              NaN                    NaN
# Technology                    25.842697               3.370787

# %% [markdown]
# #### DistanceFromHome

# %%
grouped['Trading Country'].describe().unstack()
# Out:
#         Sector
# count   Energy             75
#         Technology         89
# unique  Energy             15
#         Technology         15
# top     Energy        GERMANY
#         Technology    GERMANY
# freq    Energy             38
#         Technology         45
# dtype: object

# %% [markdown]
# #### HourlyRate

# %%
grouped['P/E Ratio'].describe().unstack()
# Out:
#        Sector
# count  Energy        73.000000
#        Technology    88.000000
# mean   Energy        10.671233
#        Technology    19.068182
# std    Energy         4.160178
#        Technology    11.357104
# min    Energy         2.000000
#        Technology     6.000000
# 25%    Energy         8.000000
#        Technology    13.000000
# 50%    Energy        11.000000
#        Technology    16.000000
# 75%    Energy        13.000000
#        Technology    23.000000
# max    Energy        20.000000
#        Technology    79.000000
# dtype: float64

# %% [markdown]
# #### MonthlyIncome

# %%
grouped['Mkt Val (Mil), USD'].describe().unstack()
# Out:
#        Sector
# count  Energy            75.000000
#        Technology        89.000000
# mean   Energy        133881.000000
#        Technology    159120.764045
# std    Energy         77034.198447
#        Technology     90756.277287
# min    Energy         75310.000000
#        Technology     75071.000000
# 25%    Energy         83318.000000
#        Technology    101794.000000
# 50%    Energy        114821.000000
#        Technology    125007.000000
# 75%    Energy        145074.000000
#        Technology    188273.000000
# max    Energy        435010.000000
#        Technology    497751.000000
# dtype: float64

# %% [markdown]
# #### YearsAtCompany

# %%
grouped['Avg Dly $ Vol (000)'].describe().unstack()
# Out:
#        Sector
# count  Energy        7.500000e+01
#        Technology    8.900000e+01
# mean   Energy        1.802039e+05
#        Technology    4.982875e+06
# std    Energy        7.297668e+05
#        Technology    3.378520e+07
# min    Energy        0.000000e+00
#        Technology    0.000000e+00
# 25%    Energy        1.650000e+01
#        Technology    3.200000e+01
# 50%    Energy        3.500000e+02
#        Technology    3.960000e+02
# 75%    Energy        8.587950e+04
#        Technology    1.453120e+05
# max    Energy        5.990811e+06
#        Technology    2.975491e+08
# dtype: float64

# %% [markdown]
# ### Comparing the means across all numerical variables

# %% [markdown]
# Although we we asked for just some specific columns, to give the HR director a better picture of how these groups compare across different variables, let's create a DataFrame that contains the mean for every numeric variable in our dataset.

# %%
# Getting the numerical columns
numeric_cols = subset_of_interest.select_dtypes(include=[np.number]).columns

# %%
# Creating an empty DataFrame
mean_comparison_df = pd.DataFrame(columns=numeric_cols, index=['Low', 'Very High'])
mean_comparison_df

# %%
grouped['Age'].mean()

# %%
# Filling the DataFrame
for var in numeric_cols:
    mean_comparison_df[var] = grouped[var].mean()

# %%
mean_comparison_df

# %%
mean_comparison_df = mean_comparison_df.transpose()
mean_comparison_df

# %% [markdown]
# ### Let's do a visualization

# %%
mean_comparison_df.plot(kind='bar', figsize=(13,4),
                                   title="Comparison of Means");

# %%
overal_means = data.mean()
normalized_mean_comparison_df = mean_comparison_df.copy()

# %%
overal_means = data.mean()
normalized_mean_comparison_df['Low'] = mean_comparison_df['Low'] / overal_means
normalized_mean_comparison_df['Very High'] = mean_comparison_df['Very High'] / overal_means

# %%
normalized_mean_comparison_df.plot(kind='bar', figsize=(13,4),
                                   title="Comparison of Normalized Means")
plt.legend(loc='lower left', bbox_to_anchor=(0.16, 1.0))
plt.text(x=-0.2, y = 1.2, s="JobSatisfaction:", fontdict={'size':14});
