# %% [markdown]
# # The Pandas library

# %% [markdown]
# **From the Pandas documentation:**
#
# **pandas** is everyone's favorite data analyis library providing fast, flexible, and expressive data structures designed to work with *relational* or table-like data (SQL table or Excel spreadsheet). It is a fundamental high-level building block for doing practical, real world data analysis in Python.

# %%
# The importing convention
import pandas as pd

# %% [markdown]
# # Opening (Reading) Files

# %% [markdown]
# ## Reading Excel File

# %%
filepath = "data\stock_data_simple.xlsx"

# %%
df = pd.read_excel(filepath)

# %% [markdown]
# ## Reading CSV File

# %%
filepath = "data\stock_data_simple.csv"

# %%
df = pd.read_csv(filepath)

# %% [markdown]
# # View/Display data

# %%
df.head()
# Out:
#     symbol                      name      sector   price  price_chg  \
# 0   APC.DE               Apple (Fra)  Technology  410.00       0.00
# 1  APCX.DE               Apple (Xet)  Technology  408.50      -2.00
# 2     AAPL                 Apple Inc  Technology  554.25      -3.11
# 3  XONA.DE         Exxon Mobil (Fra)      Energy   73.20       0.00
# 4      WBK  Westpac Banking Corp Adr   Financial   27.99      -0.37
#
#    price__chg    vol_rate  avg_dly__vol_000  mkt_val_mil_usd  pe_ratio  \
# 0    0.000000 -100.000000              1765           497751      14.0
# 1   -0.487211  -38.011541              6159           495930      14.0
# 2   -0.557987  -25.368715           6099413           494697      14.0
# 3    0.000000 -100.000000               322           435010      13.0
# 4   -1.304654   -8.477119              3780           432467      14.0
#
#                                  company_description industry_sector  \
# 0  APPLE INC. (APPLE) DESIGNS, MANUFACTURES AND M...        COMPUTER
# 1  APPLE INC. (APPLE) DESIGNS, MANUFACTURES AND M...        COMPUTER
# 2  MANUFACTURES PERSONAL COMPUTERS, MOBILE COMMUN...        COMPUTER
# 3  EXXON MOBIL CORPORATION IS A MANUFACTURER AND ...          ENERGY
# 4  AUSTRALIAN BANK PROVIDING BANKING/RELATED FINA...           BANKS
#
#             industry_group          isin         major_industry  \
# 0  Computer-Hardware/Perip  US0378331005                    NaN
# 1  Computer-Hardware/Perip  US0378331005                    NaN
# 2  Computer-Hardware/Perip  US0378331005  Computer Data Storage
# 3       Oil&Gas-Integrated  US30231G1022                    NaN
# 4            Banks-Foreign  US9612143019      Bank-Money Center
#
#     headquarters exchange_primary_listing   exchange trading_country
# 0            NaN        No (NASDAQ, AAPL)  FRANKFURT         GERMANY
# 1            NaN        No (NASDAQ, AAPL)      XETRA         GERMANY
# 2  Cupertino, CA                      Yes     NASDAQ   UNITED STATES
# 3            NaN           No (NYSE, XOM)  FRANKFURT         GERMANY
# 4      AUSTRALIA                      Yes       NYSE   UNITED STATES

# %%
df.tail()
# Out:
#       symbol                      name             sector  price  price_chg  \
# 494  DTEX.DE    Deutsche Telekom (Xet)         Technology  12.45     -0.195
# 495    BG.GB                  Bg Group             Energy  13.52      0.170
# 496     FOXA  Twenty-First Cen Fx Cl A  Consumer Cyclical  32.47     -0.140
# 497   ANZ.AU    Aus.And Nz.Banking Gp.          Financial  31.09      0.120
# 498  DEUT.IT    Deutsche Telekom (Mil)         Technology  12.40     -0.170
#
#      price__chg   vol_rate  avg_dly__vol_000  mkt_val_mil_usd  pe_ratio  \
# 494   -1.542722   4.413403            124042            75343      23.0
# 495    1.273885  58.304817             49949            75310      16.0
# 496   -0.429316 -26.565262            354171            75153      25.0
# 497    0.387472  -9.287592            169869            75132      13.0
# 498   -1.352426 -42.570255               193            75071      23.0
#
#                                    company_description industry_sector  \
# 494  DEUTSCHE TELEKOM AG IS A GERMANY-BASED INTEGRA...         TELECOM
# 495  BG GROUP PLC (BG GROUP) IS A NATURAL GAS COMPA...          ENERGY
# 496  GLOBAL MEDIA AND ENTERTAINMENT COMPANY ENGAGED...           MEDIA
# 497  AUSTRALIA AND NEW ZEALAND BANKING GROUP LIMITE...           BANKS
# 498  DEUTSCHE TELEKOM AG IS A GERMANY-BASED INTEGRA...         TELECOM
#
#               industry_group          isin           major_industry  \
# 494  Telecom Svcs-Integrated  DE0005557508  Telecommunication Equip
# 495       Oil&Gas-Integrated  GB0008762899                      NaN
# 496        Media-Diversified  US90130A1016         Media - Radio/Tv
# 497       Banks-Money Center  AU000000ANZ3        Bank-Money Center
# 498  Telecom Svcs-Integrated  DE0005557508  Telecommunication Equip
#
#      headquarters exchange_primary_listing    exchange trading_country
# 494           NaN                      Yes       XETRA         GERMANY
# 495       Reading                      Yes      LONDON  UNITED KINGDOM
# 496  New York, NY                      Yes      NASDAQ   UNITED STATES
# 497     Melbourne                      Yes  AUSTRALIAN       AUSTRALIA
# 498           NaN      No (XETRA, DTEX.DE)       MILAN           ITALY

# %% [markdown]
# # The Pandas DataFrames
#
# <img src="img/dataframe.png"><img src="img/excel_table.png">
#
# If the structure seems familiar, it's because DataFrames are very similar to a single Excel “Sheet”, but instead of referring to rows and columns with A1, yyou have the column numbers/names and row numbers.
#
# A DataFrame consists on three parts:
#
# 1. Index
# 2. Columns Names (Column Index)
# 3. Data

# %%
df.index
# Out:
# RangeIndex(start=0, stop=499, step=1)

# %%
df.columns
# Out:
# Index(['symbol', 'name', 'sector', 'price', 'price_chg', 'price__chg',
#        'vol_rate', 'avg_dly__vol_000', 'mkt_val_mil_usd', 'pe_ratio',
#        'company_description', 'industry_sector', 'industry_group', 'isin',
#        'major_industry', 'headquarters', 'exchange_primary_listing',
#        'exchange', 'trading_country'],
#       dtype='object')

# %%
df.values
# Out:
# array([['APC.DE', 'Apple (Fra)', 'Technology', ..., 'No (NASDAQ, AAPL)',
#         'FRANKFURT', 'GERMANY'],
#        ['APCX.DE', 'Apple (Xet)', 'Technology', ..., 'No (NASDAQ, AAPL)',
#         'XETRA', 'GERMANY'],
#        ['AAPL', 'Apple Inc', 'Technology', ..., 'Yes', 'NASDAQ',
#         'UNITED STATES'],
#        ...,
#        ['FOXA', 'Twenty-First Cen Fx Cl A', 'Consumer Cyclical', ...,
#         'Yes', 'NASDAQ', 'UNITED STATES'],
#        ['ANZ.AU', 'Aus.And Nz.Banking Gp.', 'Financial', ..., 'Yes',
#         'AUSTRALIAN', 'AUSTRALIA'],
#        ['DEUT.IT', 'Deutsche Telekom (Mil)', 'Technology', ...,
#         'No (XETRA, DTEX.DE)', 'MILAN', 'ITALY']], dtype=object)

# %% [markdown]
# ## Sort Data

# %%
df.sort_values("mkt_val_mil_usd", ascending=False)
# Out:
#       symbol                      name             sector   price  price_chg  \
# 0     APC.DE               Apple (Fra)         Technology  410.00      0.000
# 1    APCX.DE               Apple (Xet)         Technology  408.50     -2.000
# 2       AAPL                 Apple Inc         Technology  554.25     -3.110
# 3    XONA.DE         Exxon Mobil (Fra)             Energy   73.20      0.000
# 4        WBK  Westpac Banking Corp Adr          Financial   27.99     -0.370
# ..       ...                       ...                ...     ...        ...
# 494  DTEX.DE    Deutsche Telekom (Xet)         Technology   12.45     -0.195
# 495    BG.GB                  Bg Group             Energy   13.52      0.170
# 496     FOXA  Twenty-First Cen Fx Cl A  Consumer Cyclical   32.47     -0.140
# 497   ANZ.AU    Aus.And Nz.Banking Gp.          Financial   31.09      0.120
# 498  DEUT.IT    Deutsche Telekom (Mil)         Technology   12.40     -0.170
#
#      price__chg    vol_rate  avg_dly__vol_000  mkt_val_mil_usd  pe_ratio  \
# 0      0.000000 -100.000000              1765           497751      14.0
# 1     -0.487211  -38.011541              6159           495930      14.0
# 2     -0.557987  -25.368715           6099413           494697      14.0
# 3      0.000000 -100.000000               322           435010      13.0
# 4     -1.304654   -8.477119              3780           432467      14.0
# ..          ...         ...               ...              ...       ...
# 494   -1.542722    4.413403            124042            75343      23.0
# 495    1.273885   58.304817             49949            75310      16.0
# 496   -0.429316  -26.565262            354171            75153      25.0
# 497    0.387472   -9.287592            169869            75132      13.0
# 498   -1.352426  -42.570255               193            75071      23.0
#
#                                    company_description industry_sector  \
# 0    APPLE INC. (APPLE) DESIGNS, MANUFACTURES AND M...        COMPUTER
# 1    APPLE INC. (APPLE) DESIGNS, MANUFACTURES AND M...        COMPUTER
# 2    MANUFACTURES PERSONAL COMPUTERS, MOBILE COMMUN...        COMPUTER
# 3    EXXON MOBIL CORPORATION IS A MANUFACTURER AND ...          ENERGY
# 4    AUSTRALIAN BANK PROVIDING BANKING/RELATED FINA...           BANKS
# ..                                                 ...             ...
# 494  DEUTSCHE TELEKOM AG IS A GERMANY-BASED INTEGRA...         TELECOM
# 495  BG GROUP PLC (BG GROUP) IS A NATURAL GAS COMPA...          ENERGY
# 496  GLOBAL MEDIA AND ENTERTAINMENT COMPANY ENGAGED...           MEDIA
# 497  AUSTRALIA AND NEW ZEALAND BANKING GROUP LIMITE...           BANKS
# 498  DEUTSCHE TELEKOM AG IS A GERMANY-BASED INTEGRA...         TELECOM
#
#               industry_group          isin           major_industry  \
# 0    Computer-Hardware/Perip  US0378331005                      NaN
# 1    Computer-Hardware/Perip  US0378331005                      NaN
# 2    Computer-Hardware/Perip  US0378331005    Computer Data Storage
# 3         Oil&Gas-Integrated  US30231G1022                      NaN
# 4              Banks-Foreign  US9612143019        Bank-Money Center
# ..                       ...           ...                      ...
# 494  Telecom Svcs-Integrated  DE0005557508  Telecommunication Equip
# 495       Oil&Gas-Integrated  GB0008762899                      NaN
# 496        Media-Diversified  US90130A1016         Media - Radio/Tv
# 497       Banks-Money Center  AU000000ANZ3        Bank-Money Center
# 498  Telecom Svcs-Integrated  DE0005557508  Telecommunication Equip
#
#       headquarters exchange_primary_listing    exchange trading_country
# 0              NaN        No (NASDAQ, AAPL)   FRANKFURT         GERMANY
# 1              NaN        No (NASDAQ, AAPL)       XETRA         GERMANY
# 2    Cupertino, CA                      Yes      NASDAQ   UNITED STATES
# 3              NaN           No (NYSE, XOM)   FRANKFURT         GERMANY
# 4        AUSTRALIA                      Yes        NYSE   UNITED STATES
# ..             ...                      ...         ...             ...
# 494            NaN                      Yes       XETRA         GERMANY
# 495        Reading                      Yes      LONDON  UNITED KINGDOM
# 496   New York, NY                      Yes      NASDAQ   UNITED STATES
# 497      Melbourne                      Yes  AUSTRALIAN       AUSTRALIA
# 498            NaN      No (XETRA, DTEX.DE)       MILAN           ITALY
#
# [499 rows x 19 columns]

# %% [markdown]
# ## Selecting Data (by Columns)

# %%
df['symbol']
# Out:
# 0       APC.DE
# 1      APCX.DE
# 2         AAPL
# 3      XONA.DE
# 4          WBK
#         ...
# 494    DTEX.DE
# 495      BG.GB
# 496       FOXA
# 497     ANZ.AU
# 498    DEUT.IT
# Name: symbol, Length: 499, dtype: object

# %% [markdown]
# OR, can use column name:

# %%
df.symbol
# Out:
# 0       APC.DE
# 1      APCX.DE
# 2         AAPL
# 3      XONA.DE
# 4          WBK
#         ...
# 494    DTEX.DE
# 495      BG.GB
# 496       FOXA
# 497     ANZ.AU
# 498    DEUT.IT
# Name: symbol, Length: 499, dtype: object

# %%
# Getting more than one column
df[['symbol', 'name','sector']]
# Out:
#       symbol                      name             sector
# 0     APC.DE               Apple (Fra)         Technology
# 1    APCX.DE               Apple (Xet)         Technology
# 2       AAPL                 Apple Inc         Technology
# 3    XONA.DE         Exxon Mobil (Fra)             Energy
# 4        WBK  Westpac Banking Corp Adr          Financial
# ..       ...                       ...                ...
# 494  DTEX.DE    Deutsche Telekom (Xet)         Technology
# 495    BG.GB                  Bg Group             Energy
# 496     FOXA  Twenty-First Cen Fx Cl A  Consumer Cyclical
# 497   ANZ.AU    Aus.And Nz.Banking Gp.          Financial
# 498  DEUT.IT    Deutsche Telekom (Mil)         Technology
#
# [499 rows x 3 columns]

# %% [markdown]
# # Selecting Data
#
# ## Label vs. Location
#
# ### df.loc[row_labels, column_labels] - select data (rows and/or columns) with particular label(s).
#
# Allowed inputs are:
#
# * An integer, e.g. 5.
#
# * A list or array of integers, e.g. [4, 3, 0].
#
# * A slice object with ints, e.g. 1:7.
#
# * A boolean array.
#
# ### df.iloc[row_positions, column_positions] - select data (rows and/or columns) at integer locations.
#
# Allowed inputs are:
#
# * A single label, e.g. 5 or 'a', (note that 5 is interpreted as a label of the index, and never as an integer position along the index).
#
# * A list or array of labels, e.g. ['a', 'b', 'c'].
#
# * A slice object with labels, e.g. 'a':'f'.
#
# * A boolean array of the same length as the axis being sliced, e.g. [True, False, True].

# %% [markdown]
# ### Selecting a single row by position
# Selecting a single row by position

# %%
# selects series
df.loc[3]
# Out:
# symbol                                                                XONA.DE
# name                                                        Exxon Mobil (Fra)
# sector                                                                 Energy
# price                                                                    73.2
# price_chg                                                                 0.0
# price__chg                                                                0.0
# vol_rate                                                               -100.0
# avg_dly__vol_000                                                          322
# mkt_val_mil_usd                                                        435010
# pe_ratio                                                                 13.0
# company_description         EXXON MOBIL CORPORATION IS A MANUFACTURER AND ...
# industry_sector                                                        ENERGY
# industry_group                                             Oil&Gas-Integrated
# isin                                                             US30231G1022
# major_industry                                                            NaN
# headquarters                                                              NaN
# exchange_primary_listing                                       No (NYSE, XOM)
# exchange                                                            FRANKFURT
# trading_country                                                       GERMANY
# Name: 3, dtype: object

# %%
# selects series
df.iloc[3]
# Out:
# symbol                                                                XONA.DE
# name                                                        Exxon Mobil (Fra)
# sector                                                                 Energy
# price                                                                    73.2
# price_chg                                                                 0.0
# price__chg                                                                0.0
# vol_rate                                                               -100.0
# avg_dly__vol_000                                                          322
# mkt_val_mil_usd                                                        435010
# pe_ratio                                                                 13.0
# company_description         EXXON MOBIL CORPORATION IS A MANUFACTURER AND ...
# industry_sector                                                        ENERGY
# industry_group                                             Oil&Gas-Integrated
# isin                                                             US30231G1022
# major_industry                                                            NaN
# headquarters                                                              NaN
# exchange_primary_listing                                       No (NYSE, XOM)
# exchange                                                            FRANKFURT
# trading_country                                                       GERMANY
# Name: 3, dtype: object

# %%
# select the single row dataframe
df.loc[[3]]
# Out:
#     symbol               name  sector  price  price_chg  price__chg  vol_rate  \
# 3  XONA.DE  Exxon Mobil (Fra)  Energy   73.2        0.0         0.0    -100.0
#
#    avg_dly__vol_000  mkt_val_mil_usd  pe_ratio  \
# 3               322           435010      13.0
#
#                                  company_description industry_sector  \
# 3  EXXON MOBIL CORPORATION IS A MANUFACTURER AND ...          ENERGY
#
#        industry_group          isin major_industry headquarters  \
# 3  Oil&Gas-Integrated  US30231G1022            NaN          NaN
#
#   exchange_primary_listing   exchange trading_country
# 3           No (NYSE, XOM)  FRANKFURT         GERMANY

# %% [markdown]
# ### select the last row of the data frame - input: integer - output: series

# %%
df.iloc[-1]
# Out:
# symbol                                                                DEUT.IT
# name                                                   Deutsche Telekom (Mil)
# sector                                                             Technology
# price                                                                    12.4
# price_chg                                                               -0.17
# price__chg                                                          -1.352426
# vol_rate                                                           -42.570255
# avg_dly__vol_000                                                          193
# mkt_val_mil_usd                                                         75071
# pe_ratio                                                                 23.0
# company_description         DEUTSCHE TELEKOM AG IS A GERMANY-BASED INTEGRA...
# industry_sector                                                       TELECOM
# industry_group                                        Telecom Svcs-Integrated
# isin                                                             DE0005557508
# major_industry                                        Telecommunication Equip
# headquarters                                                              NaN
# exchange_primary_listing                                  No (XETRA, DTEX.DE)
# exchange                                                                MILAN
# trading_country                                                         ITALY
# Name: 498, dtype: object

# %%
# select the last row of the data frame - input: list - output: data frame
df.iloc[[-1]]
# Out:
#       symbol                    name      sector  price  price_chg  \
# 498  DEUT.IT  Deutsche Telekom (Mil)  Technology   12.4      -0.17
#
#      price__chg   vol_rate  avg_dly__vol_000  mkt_val_mil_usd  pe_ratio  \
# 498   -1.352426 -42.570255               193            75071      23.0
#
#                                    company_description industry_sector  \
# 498  DEUTSCHE TELEKOM AG IS A GERMANY-BASED INTEGRA...         TELECOM
#
#               industry_group          isin           major_industry  \
# 498  Telecom Svcs-Integrated  DE0005557508  Telecommunication Equip
#
#     headquarters exchange_primary_listing exchange trading_country
# 498          NaN      No (XETRA, DTEX.DE)    MILAN           ITALY

# %% [markdown]
# # Selecting multiple rows by position
# To extract multiple rows by position, we pass either a list or a slice object to the .iloc[] indexer.
#
# #### df.loc[row_labels, column_labels]
#
# #### df.iloc[row_positions, column_positions]

# %% [markdown]
# By integer slices, acting similar to numpy/Python:

# %%
# Selecting rows and columns simultaneously
rows_to_select = [22, 45, 66, 234]

# using loc
df.loc[rows_to_select]
# Out:
#       symbol                 name             sector    price  price_chg  \
# 22     NSRGY  Nestle S A Adr Spon    Consumer Staple    74.78      1.250
# 45       CVX         Chevron Corp             Energy   118.83     -0.350
# 66    TYT.GB   Toyota Motor (Xsq)  Consumer Cyclical  6285.66     53.785
# 234  SCLX.DE   Schlumberger (Xet)             Energy    64.10     -0.850
#
#      price__chg   vol_rate  avg_dly__vol_000  mkt_val_mil_usd  pe_ratio  \
# 22     1.699986 -11.522471             37140           272947      21.0
# 45    -0.293673 -12.169090            681149           228530      10.0
# 66     0.863062 -89.918662           1097351           207913      14.0
# 234   -1.308699 -92.407809                30           114821      18.0
#
#                                    company_description industry_sector  \
# 22   MANUFACTURES BEVERAGES, MILK PRODUCTS, ICE CRE...        FOOD/BEV
# 45   ENGAGED IN EXPLORATION, PRODUCTION, REFINING A...          ENERGY
# 66   TOYOTA MOTOR CORPORATION IS A JAPAN-BASED COMP...            AUTO
# 234  SCHLUMBERGER LIMITED (SCHLUMBERGER N.V.) IS TH...          ENERGY
#
#              industry_group          isin           major_industry  \
# 22            Food-Packaged  US6410694060                     Food
# 45       Oil&Gas-Integrated  US1667641005       Oil&Gas-Integrated
# 66       Auto Manufacturers  JP3633400001               Automobile
# 234  Oil&Gas-Field Services  AN8068571086  Oil&Gas-Equipment & Svc
#
#       headquarters exchange_primary_listing          exchange trading_country
# 22     SWITZERLAND                      Yes               OTC   UNITED STATES
# 45   San Ramon, CA                      Yes              NYSE   UNITED STATES
# 66           Aichi      No (TOKYO, TYMO.JP)  SEAQ INTERNATION  UNITED KINGDOM
# 234            NaN           No (NYSE, SLB)             XETRA         GERMANY

# %%
# we can select 
df['symbol'].loc[rows_to_select]
# Out:
# 22       NSRGY
# 45         CVX
# 66      TYT.GB
# 234    SCLX.DE
# Name: symbol, dtype: object

# %%
# using iloc method
df.iloc[rows_to_select]
# Out:
#       symbol                 name             sector    price  price_chg  \
# 22     NSRGY  Nestle S A Adr Spon    Consumer Staple    74.78      1.250
# 45       CVX         Chevron Corp             Energy   118.83     -0.350
# 66    TYT.GB   Toyota Motor (Xsq)  Consumer Cyclical  6285.66     53.785
# 234  SCLX.DE   Schlumberger (Xet)             Energy    64.10     -0.850
#
#      price__chg   vol_rate  avg_dly__vol_000  mkt_val_mil_usd  pe_ratio  \
# 22     1.699986 -11.522471             37140           272947      21.0
# 45    -0.293673 -12.169090            681149           228530      10.0
# 66     0.863062 -89.918662           1097351           207913      14.0
# 234   -1.308699 -92.407809                30           114821      18.0
#
#                                    company_description industry_sector  \
# 22   MANUFACTURES BEVERAGES, MILK PRODUCTS, ICE CRE...        FOOD/BEV
# 45   ENGAGED IN EXPLORATION, PRODUCTION, REFINING A...          ENERGY
# 66   TOYOTA MOTOR CORPORATION IS A JAPAN-BASED COMP...            AUTO
# 234  SCHLUMBERGER LIMITED (SCHLUMBERGER N.V.) IS TH...          ENERGY
#
#              industry_group          isin           major_industry  \
# 22            Food-Packaged  US6410694060                     Food
# 45       Oil&Gas-Integrated  US1667641005       Oil&Gas-Integrated
# 66       Auto Manufacturers  JP3633400001               Automobile
# 234  Oil&Gas-Field Services  AN8068571086  Oil&Gas-Equipment & Svc
#
#       headquarters exchange_primary_listing          exchange trading_country
# 22     SWITZERLAND                      Yes               OTC   UNITED STATES
# 45   San Ramon, CA                      Yes              NYSE   UNITED STATES
# 66           Aichi      No (TOKYO, TYMO.JP)  SEAQ INTERNATION  UNITED KINGDOM
# 234            NaN           No (NYSE, SLB)             XETRA         GERMANY

# %%
# select the first five rows of the dataframe using slice notation
df.iloc[0:5]
# Out:
#     symbol                      name      sector   price  price_chg  \
# 0   APC.DE               Apple (Fra)  Technology  410.00       0.00
# 1  APCX.DE               Apple (Xet)  Technology  408.50      -2.00
# 2     AAPL                 Apple Inc  Technology  554.25      -3.11
# 3  XONA.DE         Exxon Mobil (Fra)      Energy   73.20       0.00
# 4      WBK  Westpac Banking Corp Adr   Financial   27.99      -0.37
#
#    price__chg    vol_rate  avg_dly__vol_000  mkt_val_mil_usd  pe_ratio  \
# 0    0.000000 -100.000000              1765           497751      14.0
# 1   -0.487211  -38.011541              6159           495930      14.0
# 2   -0.557987  -25.368715           6099413           494697      14.0
# 3    0.000000 -100.000000               322           435010      13.0
# 4   -1.304654   -8.477119              3780           432467      14.0
#
#                                  company_description industry_sector  \
# 0  APPLE INC. (APPLE) DESIGNS, MANUFACTURES AND M...        COMPUTER
# 1  APPLE INC. (APPLE) DESIGNS, MANUFACTURES AND M...        COMPUTER
# 2  MANUFACTURES PERSONAL COMPUTERS, MOBILE COMMUN...        COMPUTER
# 3  EXXON MOBIL CORPORATION IS A MANUFACTURER AND ...          ENERGY
# 4  AUSTRALIAN BANK PROVIDING BANKING/RELATED FINA...           BANKS
#
#             industry_group          isin         major_industry  \
# 0  Computer-Hardware/Perip  US0378331005                    NaN
# 1  Computer-Hardware/Perip  US0378331005                    NaN
# 2  Computer-Hardware/Perip  US0378331005  Computer Data Storage
# 3       Oil&Gas-Integrated  US30231G1022                    NaN
# 4            Banks-Foreign  US9612143019      Bank-Money Center
#
#     headquarters exchange_primary_listing   exchange trading_country
# 0            NaN        No (NASDAQ, AAPL)  FRANKFURT         GERMANY
# 1            NaN        No (NASDAQ, AAPL)      XETRA         GERMANY
# 2  Cupertino, CA                      Yes     NASDAQ   UNITED STATES
# 3            NaN           No (NYSE, XOM)  FRANKFURT         GERMANY
# 4      AUSTRALIA                      Yes       NYSE   UNITED STATES

# %%
# Selecting a single row and multiple columns
# select the name, surname, and salary of the employee with id number 478 by position
df.iloc[1, [0, 1, 3]]

# select the name, surname, and salary of the employee with id number 478 by label
df.loc[44, ['symbol', 'sector', 'price']]
# Out:
# symbol      RDSA
# sector    Energy
# price      71.74
# Name: 44, dtype: object

# %% [markdown]
# ### For getting a value (cell) explicitly:

# %%
df.iloc[2, 1]
# Out:
# 'Apple Inc'

# %% [markdown]
# For getting fast access to a scalar (equivalent to the prior method):

# %%
df.iat[2, 1]
# Out:
# 'Apple Inc'

# %%
# For slicing rows explicitly:
df.iloc[1:3, :]
# Out:
#     symbol         name      sector   price  price_chg  price__chg   vol_rate  \
# 1  APCX.DE  Apple (Xet)  Technology  408.50      -2.00   -0.487211 -38.011541
# 2     AAPL    Apple Inc  Technology  554.25      -3.11   -0.557987 -25.368715
#
#    avg_dly__vol_000  mkt_val_mil_usd  pe_ratio  \
# 1              6159           495930      14.0
# 2           6099413           494697      14.0
#
#                                  company_description industry_sector  \
# 1  APPLE INC. (APPLE) DESIGNS, MANUFACTURES AND M...        COMPUTER
# 2  MANUFACTURES PERSONAL COMPUTERS, MOBILE COMMUN...        COMPUTER
#
#             industry_group          isin         major_industry  \
# 1  Computer-Hardware/Perip  US0378331005                    NaN
# 2  Computer-Hardware/Perip  US0378331005  Computer Data Storage
#
#     headquarters exchange_primary_listing exchange trading_country
# 1            NaN        No (NASDAQ, AAPL)    XETRA         GERMANY
# 2  Cupertino, CA                      Yes   NASDAQ   UNITED STATES

# %%
# The .iloc[] indexer is used to index a data frame by position.
df.iloc[2]
# Out:
# symbol                                                                   AAPL
# name                                                                Apple Inc
# sector                                                             Technology
# price                                                                  554.25
# price_chg                                                               -3.11
# price__chg                                                          -0.557987
# vol_rate                                                           -25.368715
# avg_dly__vol_000                                                      6099413
# mkt_val_mil_usd                                                        494697
# pe_ratio                                                                 14.0
# company_description         MANUFACTURES PERSONAL COMPUTERS, MOBILE COMMUN...
# industry_sector                                                      COMPUTER
# industry_group                                        Computer-Hardware/Perip
# isin                                                             US0378331005
# major_industry                                          Computer Data Storage
# headquarters                                                    Cupertino, CA
# exchange_primary_listing                                                  Yes
# exchange                                                               NASDAQ
# trading_country                                                 UNITED STATES
# Name: 2, dtype: object

# %%
# To extract multiple rows by position, we pass either a list or a slice object to the .iloc[] indexer.
df.iloc[[2]]
# Out:
#   symbol       name      sector   price  price_chg  price__chg   vol_rate  \
# 2   AAPL  Apple Inc  Technology  554.25      -3.11   -0.557987 -25.368715
#
#    avg_dly__vol_000  mkt_val_mil_usd  pe_ratio  \
# 2           6099413           494697      14.0
#
#                                  company_description industry_sector  \
# 2  MANUFACTURES PERSONAL COMPUTERS, MOBILE COMMUN...        COMPUTER
#
#             industry_group          isin         major_industry  \
# 2  Computer-Hardware/Perip  US0378331005  Computer Data Storage
#
#     headquarters exchange_primary_listing exchange trading_country
# 2  Cupertino, CA                      Yes   NASDAQ   UNITED STATES

# %%
df.iloc[rows_to_select]
# Out:
#       symbol                 name             sector    price  price_chg  \
# 22     NSRGY  Nestle S A Adr Spon    Consumer Staple    74.78      1.250
# 45       CVX         Chevron Corp             Energy   118.83     -0.350
# 66    TYT.GB   Toyota Motor (Xsq)  Consumer Cyclical  6285.66     53.785
# 234  SCLX.DE   Schlumberger (Xet)             Energy    64.10     -0.850
#
#      price__chg   vol_rate  avg_dly__vol_000  mkt_val_mil_usd  pe_ratio  \
# 22     1.699986 -11.522471             37140           272947      21.0
# 45    -0.293673 -12.169090            681149           228530      10.0
# 66     0.863062 -89.918662           1097351           207913      14.0
# 234   -1.308699 -92.407809                30           114821      18.0
#
#                                    company_description industry_sector  \
# 22   MANUFACTURES BEVERAGES, MILK PRODUCTS, ICE CRE...        FOOD/BEV
# 45   ENGAGED IN EXPLORATION, PRODUCTION, REFINING A...          ENERGY
# 66   TOYOTA MOTOR CORPORATION IS A JAPAN-BASED COMP...            AUTO
# 234  SCHLUMBERGER LIMITED (SCHLUMBERGER N.V.) IS TH...          ENERGY
#
#              industry_group          isin           major_industry  \
# 22            Food-Packaged  US6410694060                     Food
# 45       Oil&Gas-Integrated  US1667641005       Oil&Gas-Integrated
# 66       Auto Manufacturers  JP3633400001               Automobile
# 234  Oil&Gas-Field Services  AN8068571086  Oil&Gas-Equipment & Svc
#
#       headquarters exchange_primary_listing          exchange trading_country
# 22     SWITZERLAND                      Yes               OTC   UNITED STATES
# 45   San Ramon, CA                      Yes              NYSE   UNITED STATES
# 66           Aichi      No (TOKYO, TYMO.JP)  SEAQ INTERNATION  UNITED KINGDOM
# 234            NaN           No (NYSE, SLB)             XETRA         GERMANY

# %%
# Getting a single value
df.loc[1,'company_description']
# Out:
# "APPLE INC. (APPLE) DESIGNS, MANUFACTURES AND MARKETS MOBILE COMMUNICATION AND MEDIA DEVICES, PERSONAL COMPUTERS, AND PORTABLE DIGITAL MUSIC PLAYERS, AND SELLS A VARIETY OF RELATED SOFTWARE, SERVICES, PERIPHERALS, NETWORKING SOLUTIONS, AND THIRD-PARTY DIGITAL CONTENT AND APPLICATIONS. THE COMPANY'S PRODUCTS AND SERVICES INCLUDE IPHONE, IPAD, MAC, IPOD, APPLE TV, A PORTFOLIO OF CONSUMER AND PROFESSIONAL SOFTWARE APPLICATIONS, THE IOS AND OS X OPERATING SYSTEMS, ICLOUD, AND A VARIETY OF ACCESSORY, SERVICE AND SUPPORT OFFERINGS. IN MARCH 2013, THE COMPANY ACQUIRED A SILICON VALLEY STARTUP, WIFISLAM, WHICH MAKES MAPPING APPLICATIONS FOR SMART PHONES. EFFECTIVE JULY 19, 2013, APPLE ACQUIRED LOCATIONARY INC. EFFECTIVE JULY 20, 2013, APPLE ACQUIRED HOPSTOP.COM INC. EFFECTIVE AUGUST 28, 2013, APPLE ACQUIRED ALGOTRIM AB, A MALMO-BASED DEVELOPER OF PREPACKAGED SOFTWARE. IN NOVEMBER 2013, APPLE BOUGHT PRIMESE"

# %% [markdown]
# See more at Selection by Label.
#
# * df.iloc is primarily integer position based (from 0 to length-1 of the axis), but may also be used with a boolean array. .iloc will raise IndexError if a requested indexer is out-of-bounds, except slice indexers which allow out-of-bounds indexing. (this conforms with Python/NumPy slice semantics). Allowed inputs are:
#
#     * An integer e.g. 5.
#
#     * A list or array of integers [4, 3, 0].
#
#     * A slice object with ints 1:7.
#
#     * A boolean array (any NA values will be treated as False).
#
#     * A callable function with one argument (the calling Series or DataFrame) and that returns valid output for indexing (one of the above).

# %% [markdown]
# It is also possible to select by position using the *iloc* method

# %% [markdown]
# ## Describe data quick statistical summary

# %%
df.describe()
# Out:
#               price    price_chg  price__chg     vol_rate  avg_dly__vol_000  \
# count  4.990000e+02   499.000000  499.000000   486.000000      4.990000e+02
# mean   3.937696e+03     7.238984    0.122020    23.230114      1.222698e+06
# std    5.928055e+04   112.630061    1.219567   426.729572      1.469997e+07
# min    1.500000e-01  -892.000000   -4.782609  -100.000000      0.000000e+00
# 25%    2.645500e+01    -0.070000   -0.291533  -100.000000      3.350000e+01
# 50%    5.466000e+01     0.000000    0.000000   -26.303047      3.030000e+02
# 75%    1.004450e+02     0.170000    0.351560    17.051872      8.808850e+04
# max    1.301000e+06  2000.000000    9.458656  5900.000000      2.975491e+08
#
#        mkt_val_mil_usd     pe_ratio
# count        499.00000   474.000000
# mean      137938.56513    30.776371
# std        69760.05240   127.496568
# min        75071.00000     2.000000
# 25%        88903.50000    12.000000
# 50%       113659.00000    16.000000
# 75%       175293.00000    21.000000
# max       497751.00000  1414.000000

# %% [markdown]
# ## Transpose your data

# %%
df.T
# Out:
#                                                                         0    \
# symbol                                                               APC.DE
# name                                                            Apple (Fra)
# sector                                                           Technology
# price                                                                 410.0
# price_chg                                                               0.0
# price__chg                                                              0.0
# vol_rate                                                             -100.0
# avg_dly__vol_000                                                       1765
# mkt_val_mil_usd                                                      497751
# pe_ratio                                                               14.0
# company_description       APPLE INC. (APPLE) DESIGNS, MANUFACTURES AND M...
# industry_sector                                                    COMPUTER
# industry_group                                      Computer-Hardware/Perip
# isin                                                           US0378331005
# major_industry                                                          NaN
# headquarters                                                            NaN
# exchange_primary_listing                                  No (NASDAQ, AAPL)
# exchange                                                          FRANKFURT
# trading_country                                                     GERMANY
#
#                                                                         1    \
# symbol                                                              APCX.DE
# name                                                            Apple (Xet)
# sector                                                           Technology
# price                                                                 408.5
# price_chg                                                              -2.0
# price__chg                                                        -0.487211
# vol_rate                                                         -38.011541
# avg_dly__vol_000                                                       6159
# mkt_val_mil_usd                                                      495930
# pe_ratio                                                               14.0
# company_description       APPLE INC. (APPLE) DESIGNS, MANUFACTURES AND M...
# industry_sector                                                    COMPUTER
# industry_group                                      Computer-Hardware/Perip
# isin                                                           US0378331005
# major_industry                                                          NaN
# headquarters                                                            NaN
# exchange_primary_listing                                  No (NASDAQ, AAPL)
# exchange                                                              XETRA
# trading_country                                                     GERMANY
#
#                                                                         2    \
# symbol                                                                 AAPL
# name                                                              Apple Inc
# sector                                                           Technology
# price                                                                554.25
# price_chg                                                             -3.11
# price__chg                                                        -0.557987
# vol_rate                                                         -25.368715
# avg_dly__vol_000                                                    6099413
# mkt_val_mil_usd                                                      494697
# pe_ratio                                                               14.0
# company_description       MANUFACTURES PERSONAL COMPUTERS, MOBILE COMMUN...
# industry_sector                                                    COMPUTER
# industry_group                                      Computer-Hardware/Perip
# isin                                                           US0378331005
# major_industry                                        Computer Data Storage
# headquarters                                                  Cupertino, CA
# exchange_primary_listing                                                Yes
# exchange                                                             NASDAQ
# trading_country                                               UNITED STATES
#
#                                                                         3    \
# symbol                                                              XONA.DE
# name                                                      Exxon Mobil (Fra)
# sector                                                               Energy
# price                                                                  73.2
# price_chg                                                               0.0
# price__chg                                                              0.0
# vol_rate                                                             -100.0
# avg_dly__vol_000                                                        322
# mkt_val_mil_usd                                                      435010
# pe_ratio                                                               13.0
# company_description       EXXON MOBIL CORPORATION IS A MANUFACTURER AND ...
# industry_sector                                                      ENERGY
# industry_group                                           Oil&Gas-Integrated
# isin                                                           US30231G1022
# major_industry                                                          NaN
# headquarters                                                            NaN
# exchange_primary_listing                                     No (NYSE, XOM)
# exchange                                                          FRANKFURT
# trading_country                                                     GERMANY
#
#                                                                         4    \
# symbol                                                                  WBK
# name                                               Westpac Banking Corp Adr
# sector                                                            Financial
# price                                                                 27.99
# price_chg                                                             -0.37
# price__chg                                                        -1.304654
# vol_rate                                                          -8.477119
# avg_dly__vol_000                                                       3780
# mkt_val_mil_usd                                                      432467
# pe_ratio                                                               14.0
# company_description       AUSTRALIAN BANK PROVIDING BANKING/RELATED FINA...
# industry_sector                                                       BANKS
# industry_group                                                Banks-Foreign
# isin                                                           US9612143019
# major_industry                                            Bank-Money Center
# headquarters                                                      AUSTRALIA
# exchange_primary_listing                                                Yes
# exchange                                                               NYSE
# trading_country                                               UNITED STATES
#
#                                                                         5    \
# symbol                                                                  XOM
# name                                                       Exxon Mobil Corp
# sector                                                               Energy
# price                                                                 98.94
# price_chg                                                              0.16
# price__chg                                                         0.161976
# vol_rate                                                         -22.553492
# avg_dly__vol_000                                                    1201688
# mkt_val_mil_usd                                                      432220
# pe_ratio                                                               13.0
# company_description       ENGAGED IN THE EXPLORATION, PRODUCTION, TRANSP...
# industry_sector                                                      ENERGY
# industry_group                                           Oil&Gas-Integrated
# isin                                                           US30231G1022
# major_industry                                           Oil&Gas-Integrated
# headquarters                                                     Irving, TX
# exchange_primary_listing                                                Yes
# exchange                                                               NYSE
# trading_country                                               UNITED STATES
#
#                                                                         6    \
# symbol                                                              XOAX.DE
# name                                                      Exxon Mobil (Xet)
# sector                                                               Energy
# price                                                                 72.32
# price_chg                                                             -0.39
# price__chg                                                        -0.536377
# vol_rate                                                         -63.128791
# avg_dly__vol_000                                                        405
# mkt_val_mil_usd                                                      429768
# pe_ratio                                                               13.0
# company_description       EXXON MOBIL CORPORATION IS A MANUFACTURER AND ...
# industry_sector                                                      ENERGY
# industry_group                                           Oil&Gas-Integrated
# isin                                                           US30231G1022
# major_industry                                                          NaN
# headquarters                                                            NaN
# exchange_primary_listing                                     No (NYSE, XOM)
# exchange                                                              XETRA
# trading_country                                                     GERMANY
#
#                                                                         7    \
# symbol                                                                KO.PE
# name                                                        Coca Cola (Lim)
# sector                                                      Consumer Staple
# price                                                                 90.72
# price_chg                                                               0.0
# price__chg                                                              0.0
# vol_rate                                                                NaN
# avg_dly__vol_000                                                          0
# mkt_val_mil_usd                                                      400612
# pe_ratio                                                               47.0
# company_description       THE COCA-COLA COMPANY IS A BEVERAGE COMPANY. T...
# industry_sector                                                    FOOD/BEV
# industry_group                                      Beverages-Non-Alcoholic
# isin                                                           US1912161007
# major_industry                                     Beverage - Non-Alcoholic
# headquarters                                                            NaN
# exchange_primary_listing                                      No (NYSE, KO)
# exchange                                                               LIMA
# trading_country                                                        PERU
#
#                                                                         8    \
# symbol                                                                 GOOG
# name                                                             Google Inc
# sector                                                           Technology
# price                                                               1156.22
# price_chg                                                               7.6
# price__chg                                                         0.661663
# vol_rate                                                            5.16121
# avg_dly__vol_000                                                    1838251
# mkt_val_mil_usd                                                      386278
# pe_ratio                                                               27.0
# company_description       PROVIDES ONLINE SEARCH, INTERNET CONTENT SERVI...
# industry_sector                                                    INTERNET
# industry_group                                             Internet-Content
# isin                                                           US38259P5089
# major_industry                                                     Internet
# headquarters                                              Mountain View, CA
# exchange_primary_listing                                                Yes
# exchange                                                             NASDAQ
# trading_country                                               UNITED STATES
#
#                                                                         9    \
# symbol                                                              GG@X.DE
# name                                                       Google 'A' (Xet)
# sector                                                           Technology
# price                                                                849.35
# price_chg                                                               4.2
# price__chg                                                         0.496953
# vol_rate                                                          19.008264
# avg_dly__vol_000                                                       1028
# mkt_val_mil_usd                                                      319639
# pe_ratio                                                               31.0
# company_description       GOOGLE INC. (GOOGLE) IS A GLOBAL TECHNOLOGY CO...
# industry_sector                                                    INTERNET
# industry_group                                             Internet-Content
# isin                                                           US38259P5089
# major_industry                                                          NaN
# headquarters                                                            NaN
# exchange_primary_listing                                  No (NASDAQ, GOOG)
# exchange                                                              XETRA
# trading_country                                                     GERMANY
#
#                           ...  \
# symbol                    ...
# name                      ...
# sector                    ...
# price                     ...
# price_chg                 ...
# price__chg                ...
# vol_rate                  ...
# avg_dly__vol_000          ...
# mkt_val_mil_usd           ...
# pe_ratio                  ...
# company_description       ...
# industry_sector           ...
# industry_group            ...
# isin                      ...
# major_industry            ...
# headquarters              ...
# exchange_primary_listing  ...
# exchange                  ...
# trading_country           ...
#
#                                                                         489  \
# symbol                                                                  USB
# name                                                        U S Bancorp Inc
# sector                                                            Financial
# price                                                                 41.46
# price_chg                                                             -0.04
# price__chg                                                        -0.096385
# vol_rate                                                           1.862741
# avg_dly__vol_000                                                     323937
# mkt_val_mil_usd                                                       75718
# pe_ratio                                                               14.0
# company_description       HOLDING COMPANY FOR U.S. BANK OPERATING THROUG...
# industry_sector                                                       BANKS
# industry_group                                         Banks-Super Regional
# isin                                                           US9029733048
# major_industry                                          Bank-Super Regional
# headquarters                                                Minneapolis, MN
# exchange_primary_listing                                                Yes
# exchange                                                               NYSE
# trading_country                                               UNITED STATES
#
#                                                                         490  \
# symbol                                                              DTEA.DE
# name                                               Dt.Telekom Spn.Adr.(Fra)
# sector                                                           Technology
# price                                                                  12.5
# price_chg                                                               0.0
# price__chg                                                              0.0
# vol_rate                                                             -100.0
# avg_dly__vol_000                                                         18
# mkt_val_mil_usd                                                       75679
# pe_ratio                                                               24.0
# company_description       DEUTSCHE TELEKOM AG IS A GERMANY-BASED INTEGRA...
# industry_sector                                                     TELECOM
# industry_group                                      Telecom Svcs-Integrated
# isin                                                           US2515661054
# major_industry                                      Telecommunication Equip
# headquarters                                                            NaN
# exchange_primary_listing                                    No (OTC, DTEGY)
# exchange                                                          FRANKFURT
# trading_country                                                     GERMANY
#
#                                                                         491  \
# symbol                                                               DTE.NL
# name                                                 Deutsche Telekom (Ams)
# sector                                                           Technology
# price                                                                  12.5
# price_chg                                                             -0.02
# price__chg                                                        -0.159744
# vol_rate                                                         -90.344828
# avg_dly__vol_000                                                         18
# mkt_val_mil_usd                                                       75676
# pe_ratio                                                               23.0
# company_description       DEUTSCHE TELEKOM AG IS A GERMANY-BASED INTEGRA...
# industry_sector                                                     TELECOM
# industry_group                                      Telecom Svcs-Integrated
# isin                                                           DE0005557508
# major_industry                                      Telecommunication Equip
# headquarters                                                            NaN
# exchange_primary_listing                                No (XETRA, DTEX.DE)
# exchange                                                    AMSTERDAM (AEX)
# trading_country                                                 NETHERLANDS
#
#                                                                         492  \
# symbol                                                               DTE.RO
# name                                                 Deutsche Telekom (Bse)
# sector                                                           Technology
# price                                                                  56.5
# price_chg                                                              1.25
# price__chg                                                         2.262443
# vol_rate                                                             -100.0
# avg_dly__vol_000                                                          0
# mkt_val_mil_usd                                                       75526
# pe_ratio                                                               22.0
# company_description       DEUTSCHE TELEKOM AG IS A GERMANY-BASED INTEGRA...
# industry_sector                                                     TELECOM
# industry_group                                      Telecom Svcs-Integrated
# isin                                                           DE0005557508
# major_industry                                     Telecommunication Servce
# headquarters                                                            NaN
# exchange_primary_listing                                No (XETRA, DTEX.DE)
# exchange                                                          BUCHAREST
# trading_country                                                     ROMANIA
#
#                                                                         493  \
# symbol                                                              RIO1.DE
# name                                                        Rio Tinto (Fra)
# sector                                                       Basic Material
# price                                                                 39.25
# price_chg                                                               0.0
# price__chg                                                              0.0
# vol_rate                                                             -100.0
# avg_dly__vol_000                                                        306
# mkt_val_mil_usd                                                       75417
# pe_ratio                                                                NaN
# company_description       RIO TINTO PLC (RIO TINTO) IS AN INTERNATIONAL ...
# industry_sector                                                      MINING
# industry_group                                            Mining-Metal Ores
# isin                                                           GB0007188757
# major_industry                                                          NaN
# headquarters                                                        England
# exchange_primary_listing                                No (LONDON, RIO.GB)
# exchange                                                          FRANKFURT
# trading_country                                                     GERMANY
#
#                                                                         494  \
# symbol                                                              DTEX.DE
# name                                                 Deutsche Telekom (Xet)
# sector                                                           Technology
# price                                                                 12.45
# price_chg                                                            -0.195
# price__chg                                                        -1.542722
# vol_rate                                                           4.413403
# avg_dly__vol_000                                                     124042
# mkt_val_mil_usd                                                       75343
# pe_ratio                                                               23.0
# company_description       DEUTSCHE TELEKOM AG IS A GERMANY-BASED INTEGRA...
# industry_sector                                                     TELECOM
# industry_group                                      Telecom Svcs-Integrated
# isin                                                           DE0005557508
# major_industry                                      Telecommunication Equip
# headquarters                                                            NaN
# exchange_primary_listing                                                Yes
# exchange                                                              XETRA
# trading_country                                                     GERMANY
#
#                                                                         495  \
# symbol                                                                BG.GB
# name                                                               Bg Group
# sector                                                               Energy
# price                                                                 13.52
# price_chg                                                              0.17
# price__chg                                                         1.273885
# vol_rate                                                          58.304817
# avg_dly__vol_000                                                      49949
# mkt_val_mil_usd                                                       75310
# pe_ratio                                                               16.0
# company_description       BG GROUP PLC (BG GROUP) IS A NATURAL GAS COMPA...
# industry_sector                                                      ENERGY
# industry_group                                           Oil&Gas-Integrated
# isin                                                           GB0008762899
# major_industry                                                          NaN
# headquarters                                                        Reading
# exchange_primary_listing                                                Yes
# exchange                                                             LONDON
# trading_country                                              UNITED KINGDOM
#
#                                                                         496  \
# symbol                                                                 FOXA
# name                                               Twenty-First Cen Fx Cl A
# sector                                                    Consumer Cyclical
# price                                                                 32.47
# price_chg                                                             -0.14
# price__chg                                                        -0.429316
# vol_rate                                                         -26.565262
# avg_dly__vol_000                                                     354171
# mkt_val_mil_usd                                                       75153
# pe_ratio                                                               25.0
# company_description       GLOBAL MEDIA AND ENTERTAINMENT COMPANY ENGAGED...
# industry_sector                                                       MEDIA
# industry_group                                            Media-Diversified
# isin                                                           US90130A1016
# major_industry                                             Media - Radio/Tv
# headquarters                                                   New York, NY
# exchange_primary_listing                                                Yes
# exchange                                                             NASDAQ
# trading_country                                               UNITED STATES
#
#                                                                         497  \
# symbol                                                               ANZ.AU
# name                                                 Aus.And Nz.Banking Gp.
# sector                                                            Financial
# price                                                                 31.09
# price_chg                                                              0.12
# price__chg                                                         0.387472
# vol_rate                                                          -9.287592
# avg_dly__vol_000                                                     169869
# mkt_val_mil_usd                                                       75132
# pe_ratio                                                               13.0
# company_description       AUSTRALIA AND NEW ZEALAND BANKING GROUP LIMITE...
# industry_sector                                                       BANKS
# industry_group                                           Banks-Money Center
# isin                                                           AU000000ANZ3
# major_industry                                            Bank-Money Center
# headquarters                                                      Melbourne
# exchange_primary_listing                                                Yes
# exchange                                                         AUSTRALIAN
# trading_country                                                   AUSTRALIA
#
#                                                                         498
# symbol                                                              DEUT.IT
# name                                                 Deutsche Telekom (Mil)
# sector                                                           Technology
# price                                                                  12.4
# price_chg                                                             -0.17
# price__chg                                                        -1.352426
# vol_rate                                                         -42.570255
# avg_dly__vol_000                                                        193
# mkt_val_mil_usd                                                       75071
# pe_ratio                                                               23.0
# company_description       DEUTSCHE TELEKOM AG IS A GERMANY-BASED INTEGRA...
# industry_sector                                                     TELECOM
# industry_group                                      Telecom Svcs-Integrated
# isin                                                           DE0005557508
# major_industry                                      Telecommunication Equip
# headquarters                                                            NaN
# exchange_primary_listing                                No (XETRA, DTEX.DE)
# exchange                                                              MILAN
# trading_country                                                       ITALY
#
# [19 rows x 499 columns]

# %% [markdown]
# ## Answering simple questions about a dataset

# %% [markdown]
# ### How many companies are there by Sector?

# %%
df['sector'].value_counts()
# Out:
# Financial            116
# Technology            89
# Energy                75
# Health Care           63
# Consumer Staple       52
# Capital Equipment     32
# Consumer Cyclical     28
# Retail                21
# Basic Material        20
# Transportation         3
# Name: sector, dtype: int64

# %% [markdown]
# ### What is the average Market Capitalization?

# %%
df['mkt_val_mil_usd'].mean()
# Out:
# 137938.5651302605

# %% [markdown]
# ### What is the most frequent sector?

# %%
df['sector'].describe()
# Out:
# count           499
# unique           10
# top       Financial
# freq            116
# Name: sector, dtype: object

# %% [markdown]
# ## Who are the 5 largest companies?

# %%
df.sort_values('mkt_val_mil_usd', ascending=False)[:5]
# Out:
#     symbol                      name      sector   price  price_chg  \
# 0   APC.DE               Apple (Fra)  Technology  410.00       0.00
# 1  APCX.DE               Apple (Xet)  Technology  408.50      -2.00
# 2     AAPL                 Apple Inc  Technology  554.25      -3.11
# 3  XONA.DE         Exxon Mobil (Fra)      Energy   73.20       0.00
# 4      WBK  Westpac Banking Corp Adr   Financial   27.99      -0.37
#
#    price__chg    vol_rate  avg_dly__vol_000  mkt_val_mil_usd  pe_ratio  \
# 0    0.000000 -100.000000              1765           497751      14.0
# 1   -0.487211  -38.011541              6159           495930      14.0
# 2   -0.557987  -25.368715           6099413           494697      14.0
# 3    0.000000 -100.000000               322           435010      13.0
# 4   -1.304654   -8.477119              3780           432467      14.0
#
#                                  company_description industry_sector  \
# 0  APPLE INC. (APPLE) DESIGNS, MANUFACTURES AND M...        COMPUTER
# 1  APPLE INC. (APPLE) DESIGNS, MANUFACTURES AND M...        COMPUTER
# 2  MANUFACTURES PERSONAL COMPUTERS, MOBILE COMMUN...        COMPUTER
# 3  EXXON MOBIL CORPORATION IS A MANUFACTURER AND ...          ENERGY
# 4  AUSTRALIAN BANK PROVIDING BANKING/RELATED FINA...           BANKS
#
#             industry_group          isin         major_industry  \
# 0  Computer-Hardware/Perip  US0378331005                    NaN
# 1  Computer-Hardware/Perip  US0378331005                    NaN
# 2  Computer-Hardware/Perip  US0378331005  Computer Data Storage
# 3       Oil&Gas-Integrated  US30231G1022                    NaN
# 4            Banks-Foreign  US9612143019      Bank-Money Center
#
#     headquarters exchange_primary_listing   exchange trading_country
# 0            NaN        No (NASDAQ, AAPL)  FRANKFURT         GERMANY
# 1            NaN        No (NASDAQ, AAPL)      XETRA         GERMANY
# 2  Cupertino, CA                      Yes     NASDAQ   UNITED STATES
# 3            NaN           No (NYSE, XOM)  FRANKFURT         GERMANY
# 4      AUSTRALIA                      Yes       NYSE   UNITED STATES

# %% [markdown]
# # Boolean Indexing
# Boolean indexing
# Another common operation is the use of boolean vectors to filter the data. The operators are: | for or, & for and, and ~ for not.
# These must be grouped by using parentheses, since by default Python will evaluate an expression such as df['A'] > 2 & df['B'] < 3 as df['A'] > (2 & df['B']) < 3, while the desired evaluation order is (df['A'] > 2) & (df['B'] < 3).

# %%
df[df.mkt_val_mil_usd > 425010]
# Out:
#     symbol                      name      sector   price  price_chg  \
# 0   APC.DE               Apple (Fra)  Technology  410.00       0.00
# 1  APCX.DE               Apple (Xet)  Technology  408.50      -2.00
# 2     AAPL                 Apple Inc  Technology  554.25      -3.11
# 3  XONA.DE         Exxon Mobil (Fra)      Energy   73.20       0.00
# 4      WBK  Westpac Banking Corp Adr   Financial   27.99      -0.37
# 5      XOM          Exxon Mobil Corp      Energy   98.94       0.16
# 6  XOAX.DE         Exxon Mobil (Xet)      Energy   72.32      -0.39
#
#    price__chg    vol_rate  avg_dly__vol_000  mkt_val_mil_usd  pe_ratio  \
# 0    0.000000 -100.000000              1765           497751      14.0
# 1   -0.487211  -38.011541              6159           495930      14.0
# 2   -0.557987  -25.368715           6099413           494697      14.0
# 3    0.000000 -100.000000               322           435010      13.0
# 4   -1.304654   -8.477119              3780           432467      14.0
# 5    0.161976  -22.553492           1201688           432220      13.0
# 6   -0.536377  -63.128791               405           429768      13.0
#
#                                  company_description industry_sector  \
# 0  APPLE INC. (APPLE) DESIGNS, MANUFACTURES AND M...        COMPUTER
# 1  APPLE INC. (APPLE) DESIGNS, MANUFACTURES AND M...        COMPUTER
# 2  MANUFACTURES PERSONAL COMPUTERS, MOBILE COMMUN...        COMPUTER
# 3  EXXON MOBIL CORPORATION IS A MANUFACTURER AND ...          ENERGY
# 4  AUSTRALIAN BANK PROVIDING BANKING/RELATED FINA...           BANKS
# 5  ENGAGED IN THE EXPLORATION, PRODUCTION, TRANSP...          ENERGY
# 6  EXXON MOBIL CORPORATION IS A MANUFACTURER AND ...          ENERGY
#
#             industry_group          isin         major_industry  \
# 0  Computer-Hardware/Perip  US0378331005                    NaN
# 1  Computer-Hardware/Perip  US0378331005                    NaN
# 2  Computer-Hardware/Perip  US0378331005  Computer Data Storage
# 3       Oil&Gas-Integrated  US30231G1022                    NaN
# 4            Banks-Foreign  US9612143019      Bank-Money Center
# 5       Oil&Gas-Integrated  US30231G1022     Oil&Gas-Integrated
# 6       Oil&Gas-Integrated  US30231G1022                    NaN
#
#     headquarters exchange_primary_listing   exchange trading_country
# 0            NaN        No (NASDAQ, AAPL)  FRANKFURT         GERMANY
# 1            NaN        No (NASDAQ, AAPL)      XETRA         GERMANY
# 2  Cupertino, CA                      Yes     NASDAQ   UNITED STATES
# 3            NaN           No (NYSE, XOM)  FRANKFURT         GERMANY
# 4      AUSTRALIA                      Yes       NYSE   UNITED STATES
# 5     Irving, TX                      Yes       NYSE   UNITED STATES
# 6            NaN           No (NYSE, XOM)      XETRA         GERMANY

# %%
#  exclude COMPUTER sector
df[~(df.sector == "Technology")]
# Out:
#       symbol                      name             sector  price  price_chg  \
# 3    XONA.DE         Exxon Mobil (Fra)             Energy  73.20       0.00
# 4        WBK  Westpac Banking Corp Adr          Financial  27.99      -0.37
# 5        XOM          Exxon Mobil Corp             Energy  98.94       0.16
# 6    XOAX.DE         Exxon Mobil (Xet)             Energy  72.32      -0.39
# 7      KO.PE           Coca Cola (Lim)    Consumer Staple  90.72       0.00
# ..       ...                       ...                ...    ...        ...
# 489      USB           U S Bancorp Inc          Financial  41.46      -0.04
# 493  RIO1.DE           Rio Tinto (Fra)     Basic Material  39.25       0.00
# 495    BG.GB                  Bg Group             Energy  13.52       0.17
# 496     FOXA  Twenty-First Cen Fx Cl A  Consumer Cyclical  32.47      -0.14
# 497   ANZ.AU    Aus.And Nz.Banking Gp.          Financial  31.09       0.12
#
#      price__chg    vol_rate  avg_dly__vol_000  mkt_val_mil_usd  pe_ratio  \
# 3      0.000000 -100.000000               322           435010      13.0
# 4     -1.304654   -8.477119              3780           432467      14.0
# 5      0.161976  -22.553492           1201688           432220      13.0
# 6     -0.536377  -63.128791               405           429768      13.0
# 7      0.000000         NaN                 0           400612      47.0
# ..          ...         ...               ...              ...       ...
# 489   -0.096385    1.862741            323937            75718      14.0
# 493    0.000000 -100.000000               306            75417       NaN
# 495    1.273885   58.304817             49949            75310      16.0
# 496   -0.429316  -26.565262            354171            75153      25.0
# 497    0.387472   -9.287592            169869            75132      13.0
#
#                                    company_description industry_sector  \
# 3    EXXON MOBIL CORPORATION IS A MANUFACTURER AND ...          ENERGY
# 4    AUSTRALIAN BANK PROVIDING BANKING/RELATED FINA...           BANKS
# 5    ENGAGED IN THE EXPLORATION, PRODUCTION, TRANSP...          ENERGY
# 6    EXXON MOBIL CORPORATION IS A MANUFACTURER AND ...          ENERGY
# 7    THE COCA-COLA COMPANY IS A BEVERAGE COMPANY. T...        FOOD/BEV
# ..                                                 ...             ...
# 489  HOLDING COMPANY FOR U.S. BANK OPERATING THROUG...           BANKS
# 493  RIO TINTO PLC (RIO TINTO) IS AN INTERNATIONAL ...          MINING
# 495  BG GROUP PLC (BG GROUP) IS A NATURAL GAS COMPA...          ENERGY
# 496  GLOBAL MEDIA AND ENTERTAINMENT COMPANY ENGAGED...           MEDIA
# 497  AUSTRALIA AND NEW ZEALAND BANKING GROUP LIMITE...           BANKS
#
#               industry_group          isin            major_industry  \
# 3         Oil&Gas-Integrated  US30231G1022                       NaN
# 4              Banks-Foreign  US9612143019         Bank-Money Center
# 5         Oil&Gas-Integrated  US30231G1022        Oil&Gas-Integrated
# 6         Oil&Gas-Integrated  US30231G1022                       NaN
# 7    Beverages-Non-Alcoholic  US1912161007  Beverage - Non-Alcoholic
# ..                       ...           ...                       ...
# 489     Banks-Super Regional  US9029733048       Bank-Super Regional
# 493        Mining-Metal Ores  GB0007188757                       NaN
# 495       Oil&Gas-Integrated  GB0008762899                       NaN
# 496        Media-Diversified  US90130A1016          Media - Radio/Tv
# 497       Banks-Money Center  AU000000ANZ3         Bank-Money Center
#
#         headquarters exchange_primary_listing    exchange trading_country
# 3                NaN           No (NYSE, XOM)   FRANKFURT         GERMANY
# 4          AUSTRALIA                      Yes        NYSE   UNITED STATES
# 5         Irving, TX                      Yes        NYSE   UNITED STATES
# 6                NaN           No (NYSE, XOM)       XETRA         GERMANY
# 7                NaN            No (NYSE, KO)        LIMA            PERU
# ..               ...                      ...         ...             ...
# 489  Minneapolis, MN                      Yes        NYSE   UNITED STATES
# 493          England      No (LONDON, RIO.GB)   FRANKFURT         GERMANY
# 495          Reading                      Yes      LONDON  UNITED KINGDOM
# 496     New York, NY                      Yes      NASDAQ   UNITED STATES
# 497        Melbourne                      Yes  AUSTRALIAN       AUSTRALIA
#
# [410 rows x 19 columns]

# %% [markdown]
# Indexing with isin

# %%
df.symbol
# Out:
# 0       APC.DE
# 1      APCX.DE
# 2         AAPL
# 3      XONA.DE
# 4          WBK
#         ...
# 494    DTEX.DE
# 495      BG.GB
# 496       FOXA
# 497     ANZ.AU
# 498    DEUT.IT
# Name: symbol, Length: 499, dtype: object

# %%
df.symbol.isin(["AAPL", "FB", "WBK", "DTEX.DE", "FOXA", "MSFT"])
# Out:
# 0      False
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 494     True
# 495    False
# 496     True
# 497    False
# 498    False
# Name: symbol, Length: 499, dtype: bool

# %%
df[df.symbol.isin(["AAPL", "FB", "WBK", "DTEX.DE", "FOXA", "MSFT"])]
# Out:
#       symbol                      name             sector   price  price_chg  \
# 2       AAPL                 Apple Inc         Technology  554.25     -3.110
# 4        WBK  Westpac Banking Corp Adr          Financial   27.99     -0.370
# 11      MSFT            Microsoft Corp         Technology   36.89      0.130
# 160       FB         Facebook Inc Cl A         Technology   57.19     -0.410
# 494  DTEX.DE    Deutsche Telekom (Xet)         Technology   12.45     -0.195
# 496     FOXA  Twenty-First Cen Fx Cl A  Consumer Cyclical   32.47     -0.140
#
#      price__chg   vol_rate  avg_dly__vol_000  mkt_val_mil_usd  pe_ratio  \
# 2     -0.557987 -25.368715           6099413           494697      14.0
# 4     -1.304654  -8.477119              3780           432467      14.0
# 11     0.353645  -4.880698           1468683           307956      13.0
# 160   -0.711805 -48.250630           3840670           145274      79.0
# 494   -1.542722   4.413403            124042            75343      23.0
# 496   -0.429316 -26.565262            354171            75153      25.0
#
#                                    company_description industry_sector  \
# 2    MANUFACTURES PERSONAL COMPUTERS, MOBILE COMMUN...        COMPUTER
# 4    AUSTRALIAN BANK PROVIDING BANKING/RELATED FINA...           BANKS
# 11   DEVELOPS OPERATING SYSTEMS, BUSINESS SOFTWARE,...        SOFTWARE
# 160  PROVIDES A SOCIAL NETWORKING PLATFORM ENABLING...        INTERNET
# 494  DEUTSCHE TELEKOM AG IS A GERMANY-BASED INTEGRA...         TELECOM
# 496  GLOBAL MEDIA AND ENTERTAINMENT COMPANY ENGAGED...           MEDIA
#
#               industry_group          isin           major_industry  \
# 2    Computer-Hardware/Perip  US0378331005    Computer Data Storage
# 4              Banks-Foreign  US9612143019        Bank-Money Center
# 11    Computer Sftwr-Desktop  US5949181045        Computer-Software
# 160         Internet-Content  US30303M1027                 Internet
# 494  Telecom Svcs-Integrated  DE0005557508  Telecommunication Equip
# 496        Media-Diversified  US90130A1016         Media - Radio/Tv
#
#        headquarters exchange_primary_listing exchange trading_country
# 2     Cupertino, CA                      Yes   NASDAQ   UNITED STATES
# 4         AUSTRALIA                      Yes     NYSE   UNITED STATES
# 11      Redmond, WA                      Yes   NASDAQ   UNITED STATES
# 160  Menlo Park, CA                      Yes   NASDAQ   UNITED STATES
# 494             NaN                      Yes    XETRA         GERMANY
# 496    New York, NY                      Yes   NASDAQ   UNITED STATES

# %% [markdown]
# ## Further questions

# %%
df.columns
# Out:
# Index(['symbol', 'name', 'sector', 'price', 'price_chg', 'price__chg',
#        'vol_rate', 'avg_dly__vol_000', 'mkt_val_mil_usd', 'pe_ratio',
#        'company_description', 'industry_sector', 'industry_group', 'isin',
#        'major_industry', 'headquarters', 'exchange_primary_listing',
#        'exchange', 'trading_country'],
#       dtype='object')

# %% [markdown]
# ### Give me the list of the companies in the Technology Sector

# %%
df['sector'] == 'Technology'
# Out:
# 0       True
# 1       True
# 2       True
# 3      False
# 4      False
#        ...
# 494     True
# 495    False
# 496    False
# 497    False
# 498     True
# Name: sector, Length: 499, dtype: bool

# %% [markdown]
# We can use a boolean series to index a Series or a DataFrame, this is called "Masking" or boolean indexing.

# %%
df.loc[df['sector'] == 'Technology']
# Out:
#       symbol                      name      sector    price  price_chg  \
# 0     APC.DE               Apple (Fra)  Technology   410.00      0.000
# 1    APCX.DE               Apple (Xet)  Technology   408.50     -2.000
# 2       AAPL                 Apple Inc  Technology   554.25     -3.110
# 8       GOOG                Google Inc  Technology  1156.22      7.600
# 9    GG@X.DE          Google 'A' (Xet)  Technology   849.35      4.200
# ..       ...                       ...         ...      ...        ...
# 490  DTEA.DE  Dt.Telekom Spn.Adr.(Fra)  Technology    12.50      0.000
# 491   DTE.NL    Deutsche Telekom (Ams)  Technology    12.50     -0.020
# 492   DTE.RO    Deutsche Telekom (Bse)  Technology    56.50      1.250
# 494  DTEX.DE    Deutsche Telekom (Xet)  Technology    12.45     -0.195
# 498  DEUT.IT    Deutsche Telekom (Mil)  Technology    12.40     -0.170
#
#      price__chg    vol_rate  avg_dly__vol_000  mkt_val_mil_usd  pe_ratio  \
# 0      0.000000 -100.000000              1765           497751      14.0
# 1     -0.487211  -38.011541              6159           495930      14.0
# 2     -0.557987  -25.368715           6099413           494697      14.0
# 8      0.661663    5.161210           1838251           386278      27.0
# 9      0.496953   19.008264              1028           319639      31.0
# ..          ...         ...               ...              ...       ...
# 490    0.000000 -100.000000                18            75679      24.0
# 491   -0.159744  -90.344828                18            75676      23.0
# 492    2.262443 -100.000000                 0            75526      22.0
# 494   -1.542722    4.413403            124042            75343      23.0
# 498   -1.352426  -42.570255               193            75071      23.0
#
#                                    company_description industry_sector  \
# 0    APPLE INC. (APPLE) DESIGNS, MANUFACTURES AND M...        COMPUTER
# 1    APPLE INC. (APPLE) DESIGNS, MANUFACTURES AND M...        COMPUTER
# 2    MANUFACTURES PERSONAL COMPUTERS, MOBILE COMMUN...        COMPUTER
# 8    PROVIDES ONLINE SEARCH, INTERNET CONTENT SERVI...        INTERNET
# 9    GOOGLE INC. (GOOGLE) IS A GLOBAL TECHNOLOGY CO...        INTERNET
# ..                                                 ...             ...
# 490  DEUTSCHE TELEKOM AG IS A GERMANY-BASED INTEGRA...         TELECOM
# 491  DEUTSCHE TELEKOM AG IS A GERMANY-BASED INTEGRA...         TELECOM
# 492  DEUTSCHE TELEKOM AG IS A GERMANY-BASED INTEGRA...         TELECOM
# 494  DEUTSCHE TELEKOM AG IS A GERMANY-BASED INTEGRA...         TELECOM
# 498  DEUTSCHE TELEKOM AG IS A GERMANY-BASED INTEGRA...         TELECOM
#
#               industry_group          isin            major_industry  \
# 0    Computer-Hardware/Perip  US0378331005                       NaN
# 1    Computer-Hardware/Perip  US0378331005                       NaN
# 2    Computer-Hardware/Perip  US0378331005     Computer Data Storage
# 8           Internet-Content  US38259P5089                  Internet
# 9           Internet-Content  US38259P5089                       NaN
# ..                       ...           ...                       ...
# 490  Telecom Svcs-Integrated  US2515661054   Telecommunication Equip
# 491  Telecom Svcs-Integrated  DE0005557508   Telecommunication Equip
# 492  Telecom Svcs-Integrated  DE0005557508  Telecommunication Servce
# 494  Telecom Svcs-Integrated  DE0005557508   Telecommunication Equip
# 498  Telecom Svcs-Integrated  DE0005557508   Telecommunication Equip
#
#           headquarters exchange_primary_listing         exchange  \
# 0                  NaN        No (NASDAQ, AAPL)        FRANKFURT
# 1                  NaN        No (NASDAQ, AAPL)            XETRA
# 2        Cupertino, CA                      Yes           NASDAQ
# 8    Mountain View, CA                      Yes           NASDAQ
# 9                  NaN        No (NASDAQ, GOOG)            XETRA
# ..                 ...                      ...              ...
# 490                NaN          No (OTC, DTEGY)        FRANKFURT
# 491                NaN      No (XETRA, DTEX.DE)  AMSTERDAM (AEX)
# 492                NaN      No (XETRA, DTEX.DE)        BUCHAREST
# 494                NaN                      Yes            XETRA
# 498                NaN      No (XETRA, DTEX.DE)            MILAN
#
#     trading_country
# 0           GERMANY
# 1           GERMANY
# 2     UNITED STATES
# 8     UNITED STATES
# 9           GERMANY
# ..              ...
# 490         GERMANY
# 491     NETHERLANDS
# 492         ROMANIA
# 494         GERMANY
# 498           ITALY
#
# [89 rows x 19 columns]

# %% [markdown]
# ### Give me the list of the companies in the Technology Sector and United States

# %%
df.loc[(df['sector'] == 'Technology') & (df['trading_country'] == 'UNITED STATES')]
# Out:
#     symbol                      name      sector    price  price_chg  \
# 2     AAPL                 Apple Inc  Technology   554.25      -3.11
# 8     GOOG                Google Inc  Technology  1156.22       7.60
# 11    MSFT            Microsoft Corp  Technology    36.89       0.13
# 73     IBM    Intl Business Machines  Technology   188.76       1.02
# 87     CHL      China Mobile Ltd Adr  Technology    50.17      -0.22
# 98     VOD    Vodafone Group Plc Adr  Technology    38.83      -0.10
# 119      T               A T & T Inc  Technology    33.96       0.17
# 130   ORCL               Oracle Corp  Technology    38.29      -0.12
# 160     FB         Facebook Inc Cl A  Technology    57.19      -0.41
# 167  CMCSA         Comcast Corp Cl A  Technology    53.54      -0.53
# 174     VZ    Verizon Communications  Technology    48.53       0.26
# 179  CMCSK  Comcast Corp Cla Special  Technology    51.69      -0.37
# 196   INTC                Intel Corp  Technology    26.54      -0.13
# 209   QCOM              Qualcomm Inc  Technology    74.72       0.21
# 215   CSCO         Cisco Systems Inc  Technology    22.78       0.00
# 310    SAP              S A P Ag Adr  Technology    82.81      -0.20
# 342    TSM  Taiwan Semiconductor Adr  Technology    18.15       0.59
# 455   AMOV   America Movil Sab Adr A  Technology    21.85      -0.37
# 483    TEF        Telefonica S A Adr  Technology    16.85      -0.05
#
#      price__chg    vol_rate  avg_dly__vol_000  mkt_val_mil_usd  pe_ratio  \
# 2     -0.557987  -25.368715           6099413           494697      14.0
# 8      0.661663    5.161210           1838251           386278      27.0
# 11     0.353645   -4.880698           1468683           307956      13.0
# 73     0.543304   -1.631052            909319           204965      12.0
# 87    -0.436594    3.262383             50662           201693      10.0
# 98    -0.256871  -34.011403            297016           191470      25.0
# 119    0.503107  -23.260207            713753           178901      14.0
# 130   -0.312418  -28.108149            718701           172205      14.0
# 160   -0.711805  -48.250630           3840670           145274      79.0
# 167   -0.980210    2.945779            532114           140029      23.0
# 174    0.538636   26.151711            542545           138795      19.0
# 179   -0.710718   11.610547             96941           135681      22.0
# 196   -0.487439   51.838758            823050           131930      14.0
# 209    0.281841   -0.429965            765955           126234      17.0
# 215    0.000000  -19.392564           1098805           121795      11.0
# 310   -0.240934   -0.564297             76494            98709      20.0
# 342    3.359908  112.541355            178871            94120      15.0
# 455   -1.665166  -31.666667               133            78354      12.0
# 483   -0.295857  -25.918459             15088            76246      15.0
#
#                                    company_description industry_sector  \
# 2    MANUFACTURES PERSONAL COMPUTERS, MOBILE COMMUN...        COMPUTER
# 8    PROVIDES ONLINE SEARCH, INTERNET CONTENT SERVI...        INTERNET
# 11   DEVELOPS OPERATING SYSTEMS, BUSINESS SOFTWARE,...        SOFTWARE
# 73   PROVIDES IT CONSULTING SERVICES AND COMPUTER H...      BUSINS SVC
# 87   HONG KONG-BASED PROVIDER OF DIGITAL WIRELESS V...         TELECOM
# 98   U.K.-BASED PROVIDER OF DIGITAL WIRELESS VOICE ...         TELECOM
# 119  PROVIDES LOCAL EXCHANGE, LONG DISTANCE, NETWOR...         TELECOM
# 130  DEVELOPS DATABASE, MIDDLEWARE AND BUSINESS APP...        SOFTWARE
# 160  PROVIDES A SOCIAL NETWORKING PLATFORM ENABLING...        INTERNET
# 167  PROVIDES VIDEO, INTERNET, PHONE, NETWORK, AND ...         TELECOM
# 174  PROVIDES LOCAL EXCHANGE, NETWORK ACCESS, DATA,...         TELECOM
# 179  PROVIDES VIDEO, INTERNET, PHONE, NETWORK, AND ...         TELECOM
# 196  MANUFACTURES MICROPROCESSORS, CHIPSETS, NETWOR...           CHIPS
# 209  DESIGNS CDMA-BASED/RF/POWER MANAGEMENT ICS AND...           CHIPS
# 215  MANUFACTURES SWITCHES, ROUTERS AND OTHER NETWO...        COMPUTER
# 310  GERMAN DEVELOPER OF BUSINESS OPERATIONS MANAGE...        SOFTWARE
# 342  TAIWANESE MANUFACTURER OF LOGIC/MIXED-SIGNAL I...           CHIPS
# 455  MEXICAN PROVIDER OF WIRELESS VOICE AND DATA SE...         TELECOM
# 483  SPANISH PROVIDER OF LOCAL EXCHANGE, LONG DISTA...         TELECOM
#
#                industry_group          isin            major_industry  \
# 2     Computer-Hardware/Perip  US0378331005     Computer Data Storage
# 8            Internet-Content  US38259P5089                  Internet
# 11     Computer Sftwr-Desktop  US5949181045         Computer-Software
# 73     Computer-Tech Services  US4592001014         Computer-Services
# 87      Telecom Svcs- Foreign  US16941M1099  Telecommunication Servce
# 98      Telecom Svcs- Foreign  US92857W2098  Telecommunication Servce
# 119   Telecom Svcs-Integrated  US00206R1023  Telecommunication Servce
# 130   Computer Sftwr-Database  US68389X1054         Computer-Software
# 160          Internet-Content  US30303M1027                  Internet
# 167   Telecom Svcs-Cable/Satl  US20030N1019  Telecommunication Servce
# 174   Telecom Svcs-Integrated  US92343V1044  Telecommunication Servce
# 179   Telecom Svcs-Cable/Satl  US20030N2009  Telecommunication Servce
# 196    Elec-Semiconductor Mfg  US4581401001  Electronic-Semiconductor
# 209  Elec-Semicondctor Fablss  US7475251036  Electronic-Semiconductor
# 215       Computer-Networking  US17275R1023         Computer-Software
# 310  Computer Sftwr-Enterprse  US8030542042         Computer-Software
# 342    Elec-Semiconductor Mfg  US8740391003  Electronic-Semiconductor
# 455     Telecom Svcs- Foreign  US02364W2044  Telecommunication Servce
# 483     Telecom Svcs- Foreign  US8793822086  Telecommunication Servce
#
#           headquarters exchange_primary_listing exchange trading_country
# 2        Cupertino, CA                      Yes   NASDAQ   UNITED STATES
# 8    Mountain View, CA                      Yes   NASDAQ   UNITED STATES
# 11         Redmond, WA                      Yes   NASDAQ   UNITED STATES
# 73          Armonk, NY                      Yes     NYSE   UNITED STATES
# 87           HONG KONG                      Yes     NYSE   UNITED STATES
# 98      UNITED KINGDOM                      Yes   NASDAQ   UNITED STATES
# 119         Dallas, TX                      Yes     NYSE   UNITED STATES
# 130   Redwood City, CA                      Yes     NYSE   UNITED STATES
# 160     Menlo Park, CA                      Yes   NASDAQ   UNITED STATES
# 167   Philadelphia, PA                      Yes   NASDAQ   UNITED STATES
# 174       New York, NY                      Yes     NYSE   UNITED STATES
# 179   Philadelphia, PA                      Yes   NASDAQ   UNITED STATES
# 196    Santa Clara, CA                      Yes   NASDAQ   UNITED STATES
# 209      San Diego, CA                      Yes   NASDAQ   UNITED STATES
# 215       San Jose, CA                      Yes   NASDAQ   UNITED STATES
# 310            GERMANY                      Yes     NYSE   UNITED STATES
# 342             TAIWAN                      Yes     NYSE   UNITED STATES
# 455             MEXICO                      Yes   NASDAQ   UNITED STATES
# 483              SPAIN                      Yes     NYSE   UNITED STATES

# %% [markdown]
# **Grouping operations**: Split-Apply-Combine operation.
#
# By **gourping** or **group by** operations we are referring to a process involving one or more of the following steps:
#
# - **Splitting** the data into groups based on some criteria
# - **Applying** a function to each group independently
# - **Combining** the results into a data structure

# %% [markdown]
# <img src="img/split_apply_combine.png">
#
# <b>Step1 (Split): </b> The <i>groupby</i> operation <b><i>splits</b></i> the dataframe into a group of dataframes based on some criteria. Note that the grouped object is <i>not</i> a dataframe. It is a GroupBy object. It has a dictionary-like structure and is also iterable.
#
# <b>Step 2 (Analyze):</b> Once we have a grouped object we can <b><i>apply</b></i> functions or run analysis to each group, set of groups, or the entire group.
#
# <b>Step 3 (Combine):</b> We can also <b><i>combine</b></i> the results of the analysis into a new data structure(s).

# %% [markdown]
# Since we are only interested in the employees with "Low" and "Very High" JobSatisfaction levels, let's create a new DataFrame containing only those observations.

# %%
subset_of_interest = df.loc[(df['sector'] == "Technology") | (df['sector'] == "Energy")]

subset_of_interest.shape
# Out:
# (164, 19)

# %% [markdown]
# Since our JobSatisfaction variable had 4 categories, this categories have stayed in the series of this new DataFrame:

# %%
subset_of_interest['sector'].value_counts()
# Out:
# Technology    89
# Energy        75
# Name: sector, dtype: int64

# %% [markdown]
# Let's remove those categories we won't be using:

# %%
subset_of_interest['sector'].value_counts()
# Out:
# Technology    89
# Energy        75
# Name: sector, dtype: int64

# %% [markdown]
# Now we have only the employees we are interested in, we can now compare accross the variables we wanted. First let's split our new DataFrame into groups.

# %%
grouped = subset_of_interest.groupby('sector')

# %%
grouped.groups
# Out:
# {'Energy': [3, 5, 6, 28, 35, 42, 43, 44, 45, 86, 97, 101, 110, 151, 152, 154, 155, 156, 157, 161, 162, 163, 164, 165, 166, 168, 169, 170, 171, 172, 173, 176, 184, 228, 229, 230, 231, 234, 319, 321, 322, 325, 348, 352, 353, 355, 362, 364, 384, 385, 386, 387, 388, 390, 396, 398, 400, 410, 418, 424, 427, 430, 433, 435, 436, 440, 441, 443, 444, 446, 451, 467, 485, 487, 495], 'Technology': [0, 1, 2, 8, 9, 10, 11, 12, 13, 24, 67, 68, 73, 75, 76, 79, 81, 85, 87, 88, 98, 99, 102, 103, 104, 105, 115, 116, 117, 119, 120, 127, 128, 130, 160, 167, 174, 179, 182, 190, 194, 195, 196, 209, 210, 211, 212, 213, 214, 215, 216, 217, 218, 219, 220, 221, 223, 224, 226, 227, 244, 258, 281, 283, 287, 288, 289, 290, 291, 297, 301, 310, 342, 359, 360, 455, 470, 472, 473, 478, 480, 482, 483, 486, 490, 491, 492, 494, 498]}

# %%
grouped.get_group('Energy').head()
# Out:
#      symbol                     name  sector  price  price_chg  price__chg  \
# 3   XONA.DE        Exxon Mobil (Fra)  Energy  73.20       0.00    0.000000
# 5       XOM         Exxon Mobil Corp  Energy  98.94       0.16    0.161976
# 6   XOAX.DE        Exxon Mobil (Xet)  Energy  72.32      -0.39   -0.536377
# 28   CVX.BE      Chevron Cert. (Bru)  Energy  87.29       0.29    0.333333
# 35     RDSB  Royal Dutch Shell B Ads  Energy  75.42       0.35    0.466231
#
#       vol_rate  avg_dly__vol_000  mkt_val_mil_usd  pe_ratio  \
# 3  -100.000000               322           435010      13.0
# 5   -22.553492           1201688           432220      13.0
# 6   -63.128791               405           429768      13.0
# 28  766.666667                 5           256073       NaN
# 35   92.496979             68336           241329      11.0
#
#                                   company_description industry_sector  \
# 3   EXXON MOBIL CORPORATION IS A MANUFACTURER AND ...          ENERGY
# 5   ENGAGED IN THE EXPLORATION, PRODUCTION, TRANSP...          ENERGY
# 6   EXXON MOBIL CORPORATION IS A MANUFACTURER AND ...          ENERGY
# 28                                                NaN          ENERGY
# 35  ENGAGED IN EXPLORATION, PRODUCTION AND REFININ...          ENERGY
#
#         industry_group          isin      major_industry headquarters  \
# 3   Oil&Gas-Integrated  US30231G1022                 NaN          NaN
# 5   Oil&Gas-Integrated  US30231G1022  Oil&Gas-Integrated   Irving, TX
# 6   Oil&Gas-Integrated  US30231G1022                 NaN          NaN
# 28  Oil&Gas-Integrated  BE0004589306                 NaN          NaN
# 35  Oil&Gas-Integrated  US7802591070  Oil&Gas-Integrated  NETHERLANDS
#
#    exchange_primary_listing   exchange trading_country
# 3            No (NYSE, XOM)  FRANKFURT         GERMANY
# 5                       Yes       NYSE   UNITED STATES
# 6            No (NYSE, XOM)      XETRA         GERMANY
# 28                      Yes   BRUSSELS         BELGIUM
# 35                      Yes       NYSE   UNITED STATES

# %% [markdown]
# #### Age

# %%
grouped['pe_ratio']

# %%
grouped['pe_ratio'].mean()
# Out:
# sector
# Energy        10.671233
# Technology    19.068182
# Name: pe_ratio, dtype: float64

# %%
grouped['pe_ratio'].describe()
# Out:
#             count       mean        std  min   25%   50%   75%   max
# sector
# Energy       73.0  10.671233   4.160178  2.0   8.0  11.0  13.0  20.0
# Technology   88.0  19.068182  11.357104  6.0  13.0  16.0  23.0  79.0

# %%
grouped['pe_ratio'].describe().unstack()
# Out:
#        sector
# count  Energy        73.000000
#        Technology    88.000000
# mean   Energy        10.671233
#        Technology    19.068182
# std    Energy         4.160178
#        Technology    11.357104
# min    Energy         2.000000
#        Technology     6.000000
# 25%    Energy         8.000000
#        Technology    13.000000
# 50%    Energy        11.000000
#        Technology    16.000000
# 75%    Energy        13.000000
#        Technology    23.000000
# max    Energy        20.000000
#        Technology    79.000000
# dtype: float64

# %% [markdown]
# #### Department

# %%
grouped['industry_group'].value_counts().unstack()
# Out:
# industry_group  Computer Sftwr-Database  Computer Sftwr-Desktop  \
# sector
# Energy                              NaN                     NaN
# Technology                          3.0                     5.0
#
# industry_group  Computer Sftwr-Enterprse  Computer-Hardware/Perip  \
# sector
# Energy                               NaN                      NaN
# Technology                           7.0                      3.0
#
# industry_group  Computer-Networking  Computer-Tech Services  \
# sector
# Energy                          NaN                     NaN
# Technology                      4.0                     4.0
#
# industry_group  Elec-Misc Products  Elec-Semicondctor Fablss  \
# sector
# Energy                         NaN                       NaN
# Technology                    10.0                       1.0
#
# industry_group  Elec-Semiconductor Mfg  Internet-Content  \
# sector
# Energy                             NaN               NaN
# Technology                         7.0               7.0
#
# industry_group  Oil&Gas-Field Services  Oil&Gas-Integrated  \
# sector
# Energy                             9.0                55.0
# Technology                         NaN                 NaN
#
# industry_group  Oil&Gas-Intl Expl&Prod  Oil&Gas-U S Expl&Prod  \
# sector
# Energy                            10.0                    1.0
# Technology                         NaN                    NaN
#
# industry_group  Telecom Svcs- Foreign  Telecom Svcs-Cable/Satl  \
# sector
# Energy                            NaN                      NaN
# Technology                        9.0                      3.0
#
# industry_group  Telecom Svcs-Integrated  Telecom Svcs-Wireless
# sector
# Energy                              NaN                    NaN
# Technology                         23.0                    3.0

# %%
100 * grouped['industry_group'].value_counts(normalize=True).unstack()
# Out:
# industry_group  Computer Sftwr-Database  Computer Sftwr-Desktop  \
# sector
# Energy                              NaN                     NaN
# Technology                     3.370787                5.617978
#
# industry_group  Computer Sftwr-Enterprse  Computer-Hardware/Perip  \
# sector
# Energy                               NaN                      NaN
# Technology                      7.865169                 3.370787
#
# industry_group  Computer-Networking  Computer-Tech Services  \
# sector
# Energy                          NaN                     NaN
# Technology                 4.494382                4.494382
#
# industry_group  Elec-Misc Products  Elec-Semicondctor Fablss  \
# sector
# Energy                         NaN                       NaN
# Technology               11.235955                  1.123596
#
# industry_group  Elec-Semiconductor Mfg  Internet-Content  \
# sector
# Energy                             NaN               NaN
# Technology                    7.865169          7.865169
#
# industry_group  Oil&Gas-Field Services  Oil&Gas-Integrated  \
# sector
# Energy                            12.0           73.333333
# Technology                         NaN                 NaN
#
# industry_group  Oil&Gas-Intl Expl&Prod  Oil&Gas-U S Expl&Prod  \
# sector
# Energy                       13.333333               1.333333
# Technology                         NaN                    NaN
#
# industry_group  Telecom Svcs- Foreign  Telecom Svcs-Cable/Satl  \
# sector
# Energy                            NaN                      NaN
# Technology                   10.11236                 3.370787
#
# industry_group  Telecom Svcs-Integrated  Telecom Svcs-Wireless
# sector
# Energy                              NaN                    NaN
# Technology                    25.842697               3.370787

# %% [markdown]
# #### DistanceFromHome

# %%
grouped['trading_country'].describe().unstack()
# Out:
#         sector
# count   Energy             75
#         Technology         89
# unique  Energy             15
#         Technology         15
# top     Energy        GERMANY
#         Technology    GERMANY
# freq    Energy             38
#         Technology         45
# dtype: object

# %% [markdown]
# #### HourlyRate

# %%
grouped['pe_ratio'].describe().unstack()
# Out:
#        sector
# count  Energy        73.000000
#        Technology    88.000000
# mean   Energy        10.671233
#        Technology    19.068182
# std    Energy         4.160178
#        Technology    11.357104
# min    Energy         2.000000
#        Technology     6.000000
# 25%    Energy         8.000000
#        Technology    13.000000
# 50%    Energy        11.000000
#        Technology    16.000000
# 75%    Energy        13.000000
#        Technology    23.000000
# max    Energy        20.000000
#        Technology    79.000000
# dtype: float64

# %% [markdown]
# #### MonthlyIncome

# %%
grouped['mkt_val_mil_usd'].describe().unstack()
# Out:
#        sector
# count  Energy            75.000000
#        Technology        89.000000
# mean   Energy        133881.000000
#        Technology    159120.764045
# std    Energy         77034.198447
#        Technology     90756.277287
# min    Energy         75310.000000
#        Technology     75071.000000
# 25%    Energy         83318.000000
#        Technology    101794.000000
# 50%    Energy        114821.000000
#        Technology    125007.000000
# 75%    Energy        145074.000000
#        Technology    188273.000000
# max    Energy        435010.000000
#        Technology    497751.000000
# dtype: float64

# %% [markdown]
# #### YearsAtCompany

# %%
grouped['avg_dly__vol_000'].describe().unstack()
# Out:
#        sector
# count  Energy        7.500000e+01
#        Technology    8.900000e+01
# mean   Energy        1.802039e+05
#        Technology    4.982875e+06
# std    Energy        7.297668e+05
#        Technology    3.378520e+07
# min    Energy        0.000000e+00
#        Technology    0.000000e+00
# 25%    Energy        1.650000e+01
#        Technology    3.200000e+01
# 50%    Energy        3.500000e+02
#        Technology    3.960000e+02
# 75%    Energy        8.587950e+04
#        Technology    1.453120e+05
# max    Energy        5.990811e+06
#        Technology    2.975491e+08
# dtype: float64

# %% [markdown]
# ### Comparing the means across all numerical variables

# %% [markdown]
# Although we we asked for just some specific columns, to give the HR director a better picture of how these groups compare across different variables, let's create a DataFrame that contains the mean for every numeric variable in our dataset.

# %%
# Getting the numerical columns
numeric_cols = subset_of_interest.select_dtypes(include=[np.number]).columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-245-3a87b92e4279> in <module>
#       1 # Getting the numerical columns
# ----> 2 numeric_cols = subset_of_interest.select_dtypes(include=[np.number]).columns
#
# NameError: name 'np' is not defined

# %%
# Creating an empty DataFrame
mean_comparison_df = pd.DataFrame(columns=numeric_cols, index=['Low', 'Very High'])
mean_comparison_df

# %%
grouped['Age'].mean()

# %%
# Filling the DataFrame
for var in numeric_cols:
    mean_comparison_df[var] = grouped[var].mean()

# %%
mean_comparison_df

# %%
mean_comparison_df = mean_comparison_df.transpose()
mean_comparison_df

# %% [markdown]
# ### Let's do a visualization

# %%
mean_comparison_df.plot(kind='bar', figsize=(13,4),
                                   title="Comparison of Means");

# %%
overal_means = df.mean()
normalized_mean_comparison_df = mean_comparison_df.copy()

# %%
overal_means = df.mean()
normalized_mean_comparison_df['Low'] = mean_comparison_df['Low'] / overal_means
normalized_mean_comparison_df['Very High'] = mean_comparison_df['Very High'] / overal_means

# %%
normalized_mean_comparison_df.plot(kind='bar', figsize=(13,4),
                                   title="Comparison of Normalized Means")
plt.legend(loc='lower left', bbox_to_anchor=(0.16, 1.0))
plt.text(x=-0.2, y = 1.2, s="JobSatisfaction:", fontdict={'size':14});
